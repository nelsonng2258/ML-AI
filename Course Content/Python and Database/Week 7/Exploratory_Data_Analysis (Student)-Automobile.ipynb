# %% [markdown]
# ## Exploratory Data Analysis - Automobile

# %% [markdown]
# ## Automobile Price Data
#
# ### Introduction
#
#
# ### Data Dictionary

# %% [markdown]
# # Objective
#
# The aim is to build a predictive model and find out the sales of each product at a particular store. Using this model, to understand the **properties of advertisements which play a key role in increasing sales.**

# %% [markdown]
# ------------------------

# %% [markdown]
# # Hypothesis Generation

# %% [markdown]
# **Exploratory Data Analysis refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,
# to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.**

# %% [markdown]
# So the idea is to find out the properties of a product, and store which impacts the sales of a product. Let’s think about some of the analysis that can be done and come up with certain hypothesis.

# %% [markdown]
# The Hypotheses
# I came up with the following hypothesis while thinking about the problem. These are just my thoughts and you can come-up with many more of these. Since we’re talking about stores and products, lets make different sets for each.

# %% [markdown]
# **Store Level Hypotheses:**
#
# `City type:` Stores located in urban or Tier 1 cities should have higher sales because of the higher income levels of people there.
#
# `Population Density:` Stores located in densely populated areas should have higher sales because of more demand.
#
# `Store Capacity:` Stores which are very big in size should have higher sales as they act like one-stop-shops and people would prefer getting everything from one place.
# Competitors: Stores having similar establishments nearby should have less sales because of more competition.
#
# `Marketing:` Stores which have a good marketing division should have higher sales as it will be able to attract customers through the right offers and advertising.
#
# `Location:` Stores located within popular marketplaces should have higher sales because of better access to customers.
#
# `Customer Behavior:` Stores keeping the right set of products to meet the local needs of customers will have higher sales.
#
# `Ambiance:` Stores which are well-maintained and managed by polite and humble people are expected to have higher footfall and thus higher sales.
#
# **Product Level Hypotheses:**
#
# `Brand:` Branded products should have higher sales because of higher trust in the customer.
# Packaging: Products with good packaging can attract customers and sell more.
#
# `Utility:` Daily use products should have a higher tendency to sell as compared to the specific use products.
#
# `Display Area:` Products which are given bigger shelves in the store are likely to catch attention first and sell more.
#
# `Visibility in Store:` The location of product in a store will impact sales. Ones which are right at entrance will catch the eye of customer first rather than the ones in back.
#
# `Advertising:` Better advertising of products in the store will should higher sales in most cases.
#
# `Promotional Offers:` Products accompanied with attractive offers and discounts will sell more.

# %% [markdown]
# # OR

# %% [markdown]
# ### Following are some of the hypotheses based on the problem statement.
#
# 1. Sales are higher during weekends.
# 2. Higher sales during morning and late evening.
# 3. Higher sales during end of the year.
# 4. Store size affects the sales.
# 5. Location of the store affects the sales.
# 6. Items with more shelf space sell more.

# %% [markdown]
# You can come up with more hypotheses of your own, the more the better. Let’s begin exploring the dataset and try to find interesting patterns.
#
# We’ll first load the required packages.

# %% [markdown]
# # Data Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-48-d43eab4e982d> in <module>
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 from pandas import pandas_profiling
#
# ImportError: cannot import name 'pandas_profiling' from 'pandas' (C:\Users\jymch\anaconda3\lib\site-packages\pandas\__init__.py)

# %%
#Read the data set

# %%
df = pd.read_csv('automobile.csv')

# %%
df.profile_report()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-f9a7584e785c> in <module>
# ----> 1 df.profile_report()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'profile_report'

# %%
df.head(2)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
#
# [2 rows x 26 columns]

# %%
df.tail(2)
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# 199          idi  3.01    3.40              23.0        106      4800
# 200         mpfi  3.78    3.15               9.5        114      5400
#
#     city_mpg  highway_mpg  price
# 199       26           27  22470
# 200       19           25  22625
#
# [2 rows x 26 columns]

# %%
df.shape
# Out:
# (201, 26)

# %%
df.shape[0] # Number of Rows
# Out:
# 201

# %%
df.shape[1] # Number of Columns
# Out:
# 26

# %%
df.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
df.describe().columns # To identify which is categorical, which is numerical
# Out:
# Index(['symboling', 'normalized_losses', 'wheel_base', 'length', 'width',
#        'height', 'curb_weight', 'engine_size', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
#  15  number_of_cylinders  201 non-null    object
#  16  engine_size          201 non-null    int64
#  17  fuel_system          201 non-null    object
#  18  bore                 201 non-null    float64
#  19  stroke               201 non-null    float64
#  20  compression_ratio    201 non-null    float64
#  21  horsepower           201 non-null    int64
#  22  peak_rpm             201 non-null    int64
#  23  city_mpg             201 non-null    int64
#  24  highway_mpg          201 non-null    int64
#  25  price                201 non-null    int64
# dtypes: float64(7), int64(9), object(10)
# memory usage: 41.0+ KB

# %%
df.describe(include='O').columns # Object means categorical.
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'number_of_doors', 'body_style',
#        'drive_wheels', 'engine_location', 'engine_type', 'number_of_cylinders',
#        'fuel_system'],
#       dtype='object')

# %%
df.select_dtypes(include='float')[1:3]
# Out:
#    wheel_base  length  width  height  bore  stroke  compression_ratio
# 1        88.6   168.8   64.1    48.8  3.47    2.68                9.0
# 2        94.5   171.2   65.5    52.4  2.68    3.47                9.0

# %%
df.select_dtypes(include='O')[1:3]
# Out:
#           make fuel_type aspiration number_of_doors   body_style drive_wheels  \
# 1  alfa-romero       gas        std             two  convertible          rwd
# 2  alfa-romero       gas        std             two    hatchback          rwd
#
#   engine_location engine_type number_of_cylinders fuel_system
# 1           front        dohc                four        mpfi
# 2           front        ohcv                 six        mpfi

# %% [markdown]
# **One of the key challenges in any data set is missing values. Lets start by checking which columns contain missing values.**

# %%
#df.apply(lambda x: sum(x.isnull()))

# %%
df.isnull().sum()
# Out:
# symboling              0
# normalized_losses      0
# make                   0
# fuel_type              0
# aspiration             0
# number_of_doors        0
# body_style             0
# drive_wheels           0
# engine_location        0
# wheel_base             0
# length                 0
# width                  0
# height                 0
# curb_weight            0
# engine_type            0
# number_of_cylinders    0
# engine_size            0
# fuel_system            0
# bore                   0
# stroke                 0
# compression_ratio      0
# horsepower             0
# peak_rpm               0
# city_mpg               0
# highway_mpg            0
# price                  0
# dtype: int64

# %% [markdown]
# We will impute the missing values in `Item_Weight` and `Outlet_Size` in the data cleaning section.

# %% [markdown]
# **Lets look at some basic statistics for numerical variables.**

# %%
df.describe()
# Out:
#         symboling  normalized_losses  wheel_base      length       width  \
# count  201.000000         201.000000  201.000000  201.000000  201.000000
# mean     0.840796         125.189055   98.797015  174.200995   65.889055
# std      1.254802          33.572966    6.066366   12.322175    2.101471
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.800000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.500000   66.600000
# max      3.000000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb_weight  engine_size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean    53.766667  2555.666667   126.875622    3.329701    3.261741
# std      2.447822   517.296727    41.546834    0.268166    0.317875
# min     47.800000  1488.000000    61.000000    2.540000    2.070000
# 25%     52.000000  2169.000000    98.000000    3.150000    3.110000
# 50%     54.100000  2414.000000   120.000000    3.310000    3.290000
# 75%     55.500000  2926.000000   141.000000    3.580000    3.460000
# max     59.800000  4066.000000   326.000000    3.940000    4.170000
#
#        compression_ratio  horsepower     peak_rpm    city_mpg  highway_mpg  \
# count         201.000000  201.000000   201.000000  201.000000   201.000000
# mean           10.164279  103.263682  5121.393035   25.179104    30.686567
# std             4.004965   37.389372   479.624905    6.423220     6.815150
# min             7.000000   48.000000  4150.000000   13.000000    16.000000
# 25%             8.600000   70.000000  4800.000000   19.000000    25.000000
# 50%             9.000000   95.000000  5200.000000   24.000000    30.000000
# 75%             9.400000  116.000000  5500.000000   30.000000    34.000000
# max            23.000000  262.000000  6600.000000   49.000000    54.000000
#
#               price
# count    201.000000
# mean   13207.129353
# std     7947.066342
# min     5118.000000
# 25%     7775.000000
# 50%    10295.000000
# 75%    16500.000000
# max    45400.000000

# %% [markdown]
# **Some observations:**
#
# - Item_Visibility has a min value of zero. This makes no practical sense because when a product is being sold in a store, the visibility cannot be 0.
# - Outlet_Establishment_Years vary from 1985 to 2009. The values might not be usefull in this form. Rather, if we can convert them to how old the particular store is, it should have a better impact on sales.
# - The lower 'count' of Item_Weight and Item_Outlet_Sales confirms the findings from the missing value check.

# %% [markdown]
# Statictics for categorical variable

# %%
df.describe(include='O')
# Out:
#           make fuel_type aspiration number_of_doors body_style drive_wheels  \
# count      201       201        201             201        201          201
# unique      22         2          2               2          5            3
# top     toyota       gas        std            four      sedan          fwd
# freq        32       181        165             114         94          118
#
#        engine_location engine_type number_of_cylinders fuel_system
# count              201         201                 201         201
# unique               2           6                   7           8
# top              front         ohc                four        mpfi
# freq               198         145                 157          92

# %%
#OR
#df.apply(lambda x: len(x.unique()))

# %% [markdown]
# We can see that, Item_Type has 16 unique values.
# Let’s explore further using the frequency of different categories in each nominal variable. I will exclude the ID variables for obvious reasons.

# %%
#Filter categorical variables
categorical_columns = [x for x in df.dtypes.index if df.dtypes[x]=='object']

#Exclude ID cols and source:
#categorical_columns = [x for x in categorical_columns if x not in ['Item_Identifier','Outlet_Identifier']]

#Print frequency of categories
for col in categorical_columns:
    print(f'\nVariable: {col} |Frequency of Categories for variable {col}.')
    print(df[col].value_counts())
    print("******************************************************")
# Out:
# Variable: make |Frequency of Categories for variable make.
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# volkswagen       12
# subaru           12
# volvo            11
# peugot           11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# saab              6
# audi              6
# porsche           4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# isuzu             2
# renault           2
# mercury           1
# Name: make, dtype: int64
# ******************************************************
#
# Variable: fuel_type |Frequency of Categories for variable fuel_type.
# gas       181
# diesel     20
# Name: fuel_type, dtype: int64
# ******************************************************
#
# Variable: aspiration |Frequency of Categories for variable aspiration.
# std      165
# turbo     36
# Name: aspiration, dtype: int64
# ******************************************************
#
# Variable: number_of_doors |Frequency of Categories for variable number_of_doors.
# four    114
# two      87
# Name: number_of_doors, dtype: int64
# ******************************************************
#
# Variable: body_style |Frequency of Categories for variable body_style.
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# convertible     6
# Name: body_style, dtype: int64
# ******************************************************
#
# Variable: drive_wheels |Frequency of Categories for variable drive_wheels.
# fwd    118
# rwd     75
# 4wd      8
# Name: drive_wheels, dtype: int64
# ******************************************************
#
# Variable: engine_location |Frequency of Categories for variable engine_location.
# front    198
# rear       3
# Name: engine_location, dtype: int64
# ******************************************************
#
# Variable: engine_type |Frequency of Categories for variable engine_type.
# ohc      145
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# Name: engine_type, dtype: int64
# ******************************************************
#
# Variable: number_of_cylinders |Frequency of Categories for variable number_of_cylinders.
# four      157
# six        24
# five       10
# eight       4
# two         4
# twelve      1
# three       1
# Name: number_of_cylinders, dtype: int64
# ******************************************************
#
# Variable: fuel_system |Frequency of Categories for variable fuel_system.
# mpfi    92
# 2bbl    64
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuel_system, dtype: int64
# ******************************************************

# %% [markdown]
# **The output gives us following observation:**
#
# - Item_Fat_Content: Some of 'Low Fat' values mis-coded as 'low fat' and 'LF'. Also, some of 'Regular' are mentioned as ‘regular’.

# %% [markdown]
# # Data Cleaning
# This step typically involves imputing missing values and treating outliers. Though outlier removal is very important in regression techniques, advanced tree based algorithms are impervious to outliers. So I'll leave it to you to try it out. We'll focus on the imputation step here, which is a very important step.

# %% [markdown]
# ### Imputing Missing Values
# We found two variables with missing values – Item_Weight and Outlet_Size. Lets impute the former by the average weight of the particular item.

# %%
# Chck the percentage of missing values in each variable

# %%
def null_value_percent(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (total/df.shape[0]*100)
    return pd.concat([total,percent],axis=1,keys=['total','percent'])

# %%
null_value_percent(df)
# Out:
#                      total  percent
# price                    0      0.0
# highway_mpg              0      0.0
# normalized_losses        0      0.0
# make                     0      0.0
# fuel_type                0      0.0
# aspiration               0      0.0
# number_of_doors          0      0.0
# body_style               0      0.0
# drive_wheels             0      0.0
# engine_location          0      0.0
# wheel_base               0      0.0
# length                   0      0.0
# width                    0      0.0
# height                   0      0.0
# curb_weight              0      0.0
# engine_type              0      0.0
# number_of_cylinders      0      0.0
# engine_size              0      0.0
# fuel_system              0      0.0
# bore                     0      0.0
# stroke                   0      0.0
# compression_ratio        0      0.0
# horsepower               0      0.0
# peak_rpm                 0      0.0
# city_mpg                 0      0.0
# symboling                0      0.0

# %%
for i in df.describe().columns:
    df[i] = df[i].fillna(df[i].mean())
for j in df.describe(include='O').columns:
    df[j] = df[j].fillna(df[j].mode()[0])

# %%
# check  the null values after imputation

# %%
df.isnull().sum()
# Out:
# symboling              0
# normalized_losses      0
# make                   0
# fuel_type              0
# aspiration             0
# number_of_doors        0
# body_style             0
# drive_wheels           0
# engine_location        0
# wheel_base             0
# length                 0
# width                  0
# height                 0
# curb_weight            0
# engine_type            0
# number_of_cylinders    0
# engine_size            0
# fuel_system            0
# bore                   0
# stroke                 0
# compression_ratio      0
# horsepower             0
# peak_rpm               0
# city_mpg               0
# highway_mpg            0
# price                  0
# dtype: int64

# %% [markdown]
# This confirms that the columns has no missing values now

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Univariant Analysis

# %% [markdown]
# **numeric variables**
# Now let’s check the numeric variables. We' ll again use the histograms for visualizations because that will help us in visualizing the distribution of individual variables.

# %%
#df.describe().columns

# %%
fig, ax = plt.subplots(figsize=(18, 5))
color = ["#00798c", "#d1495b", '#edae49', '#66a182',"#00798c", "#d1495b", '#edae49', '#66a182',"#00798c", "#d1495b", '#edae49', '#66a182']

for i, medium in enumerate(categorical_columns):
    print(i, medium)
    ax.subplots(i)
    ax.hist(df[medium].sort_values(), color=color[i], bins = 100, alpha = 0.6)
    plt.show()
    
for s in ['top', 'right']:
    ax.spines[s].set_visible(False)

ax.set_ylabel('Advertising Mediums')
ax.set_xlabel('')
ax.set_xlim(-1,100)
# ax.legend(loc='upper left')
ax.grid(axis = 'y')
plt.show()
plt.tight_layout()
# Out:
# 0 make
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-f6295a77560a> in <module>
#       4 for i, medium in enumerate(categorical_columns):
#       5     print(i, medium)
# ----> 6     ax.subplots(i)
#       7     ax.hist(df[medium].sort_values(), color=color[i], bins = 100, alpha = 0.6)
#       8     plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'subplots'

# %%
plt.hist(df.TV, bins = 100)
#sns.distplot(df.Item_Outlet_Sales)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-c73d585f06d8> in <module>
# ----> 1 plt.hist(df.TV, bins = 100)
#       2 #sns.distplot(df.Item_Outlet_Sales)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'TV'

# %% [markdown]
# As you can see, it is a right skewd variable and would need some data transformation to treat its skewness.

# %%
fig, ax = plt.subplots(1, 1, figsize=(18, 5))
color = ["#00798c", "#d1495b", '#edae49', '#66a182']

for medium in df.columns:
    sns.distplot(df[medium], bins = 100)
    
ax.set_xlim(0,100)
# Out:
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (0.0, 100.0)

# %%
plt.hist(df.Item_MRP)
# Out:
# (array([ 923.,  573., 1053., 1248.,  804., 1098., 1200.,  480.,  557.,
#          587.]),
#  array([ 31.29   ,  54.84984,  78.40968, 101.96952, 125.52936, 149.0892 ,
#         172.64904, 196.20888, 219.76872, 243.32856, 266.8884 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df.Item_Weight)
# Out:
# (array([ 483.,  870.,  865.,  664., 2242.,  629.,  755.,  735.,  677.,
#          603.]),
#  array([ 4.555 ,  6.2345,  7.914 ,  9.5935, 11.273 , 12.9525, 14.632 ,
#         16.3115, 17.991 , 19.6705, 21.35  ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df.Item_Visibility)
# Out:
# (array([2639., 2329., 1563.,  979.,  593.,  279.,   60.,   35.,   29.,
#           17.]),
#  array([0.        , 0.03283909, 0.06567819, 0.09851728, 0.13135638,
#         0.16419547, 0.19703457, 0.22987366, 0.26271276, 0.29555185,
#         0.32839095]),
#  <a list of 10 Patch objects>)

# %%
b = np.sqrt(df.Item_Visibility)

# %%
sns.distplot(b)
# Out:
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# As you can see, there is no clear pattern in Item_Weight and Item_MRP. However, Item_Visibility is right-skewed and should be transformed to curb its skewness.

# %%
sns.boxplot(df.Item_Outlet_Sales)
# Out:
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.pairplot(df[['Item_Weight', 'Item_Visibility', 'Item_MRP']])
plt.show()

# %% [markdown]
# **categorical variables**
# Now we will try to explore and gain some insights from the categorical variables. A categorical variable or feature can have only a finite set of values. Let’s first plot Item_Fat_Content.

# %%
df.Item_Fat_Content.value_counts().plot.bar() # Bar chart for categorical variable.

# %% [markdown]
# In the figure above, 'LF', 'low fat', and 'Low Fat' are the same category and can be combined into one. Similarly we can be done for 'reg' and 'Regular' into one. After making these corrections we will plot the same figure again.

# %%
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace({'LF':'Low Fat',
                                                             'reg':'Regular',
                                                             'low fat':'Low Fat'})
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
df.Item_Fat_Content.value_counts().plot.bar()

# %%
sns.countplot(df['Item_Fat_Content'])
# Out:
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Now let’s check the other categorical variables.

# %%
sns.countplot(df['Outlet_Size'])
# Out:
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#df.Outlet_Type.value_counts().plot.barh(color='orange')
plt.figure(figsize=(8,4))
sns.countplot(df['Outlet_Type'])
# Out:
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Supermarket Type 1 seems to be the most popular category of Outlet_Type.

# %%
plt.figure(figsize=(25,8))
sns.countplot(df['Item_Type'])
#df.Item_Type.value_counts().plot.bar()
# Out:
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Bivariate Analysis
# After looking at every feature individually, let’s now explore them again with respect to the target variable. Here we will make use of scatter plots for continuous or numeric variables and violin plots for the categorical variables.

# %%
sns.jointplot(df['Item_Weight'], df['Item_Outlet_Sales'])
# Out:
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(df['Item_Visibility'], df['Item_Outlet_Sales'])
# Out:
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10,10))
plt.xlabel('MRP')
plt.ylabel('Sales')
plt.title('MRP vs Sales')
plt.scatter(df.Item_MRP,df.Item_Outlet_Sales)

# %% [markdown]
# Item_Outlet_Sales is spread well across the entire range of the Item_Weight without any obvious pattern. In the Item_Visibility vs Item_Outlet_Sales, there is a string of points at Item_Visibility = 0.0 which seems strange as item visibility cannot be completely zero.
#
# In the third plot of Item_MRP vs Item_Outlet_Sales, we can clearly see 4 segments of prices that can be used in feature engineering to create a new variable.

# %% [markdown]
# Now we’ll visualise the categorical variables with respect to Item_Outlet_Sales. We will try to check the distribution of the target variable across all the categories of each of the categorical variable.

# %%
#sns.boxplot(df.Item_MRP)
sns.stripplot(df['Item_Fat_Content'], df['Item_Outlet_Sales'])
# Out:
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(25,4))
sns.boxplot(df['Item_Type'], df['Item_Outlet_Sales'])
# Out:
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(df['Outlet_Size'], df['Item_Outlet_Sales'])
# Out:
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(8,4))
sns.barplot(df['Outlet_Type'], df['Item_Outlet_Sales'])
# Out:
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# In the Outlet_Type, Grocery Store has most of its data points around the lower sales values as compared to the other categories.

# %%
plt.figure(figsize=(10,4))
sns.barplot(df['Outlet_Identifier'], df['Item_Outlet_Sales'])
# Out:
# C:\Users\jymch\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Distribution of Item_Outlet_Sales across the categories of Item_Type is not very distinct and same is the case with Item_Fat_Content. However, the distribution for OUT010 and OUT019 categories of Outlet_Identifier are quite similar and very much different from the rest of the categories of Outlet_Identifier.
#
# These are the kind of insights that we can extract by visualizing our data. Hence, data visualization should be an important part of any kind data analysis.

# %%
pd.crosstab(df.Item_Fat_Content,df.Item_Type)
# Out:
# Item_Type         Baking Goods  Breads  Breakfast  Canned  Dairy  \
# Item_Fat_Content
# Low Fat                    329     140         41     341    418
# Regular                    319     111         69     308    264
#
# Item_Type         Frozen Foods  Fruits and Vegetables  Hard Drinks  \
# Item_Fat_Content
# Low Fat                    450                    630          214
# Regular                    406                    602            0
#
# Item_Type         Health and Hygiene  Household  Meat  Others  Seafood  \
# Item_Fat_Content
# Low Fat                          520        910   170     169       37
# Regular                            0          0   255       0       27
#
# Item_Type         Snack Foods  Soft Drinks  Starchy Foods
# Item_Fat_Content
# Low Fat                   692          374             82
# Regular                   508           71             66
