# %% [markdown]
# # How to Run Hadoop wordcount MapReduce?

# %% [markdown]
# ## Hadoop Operation
# 1. **Open cmd in Administrative mode and move to “C:\Hadoop\hadoop-3.1.0\sbin” and start cluster**

# %%
Start-all.cmd

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **2. Create an input directory in HDFS.**

# %%
hadoop fs -mkdir /input_dir

# %% [markdown]
# **3. Copy the input text file named input_file.txt in the input directory (input_dir)of HDFS.**

# %%
hadoop fs -put C:/input_file.txt /input_dir

# %% [markdown]
# **4. Verify input_file.txt available in HDFS input directory (input_dir).**

# %%
hadoop fs -ls /input_dir/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **5. Verify content of the copied file.**

# %%
hadoop dfs -cat /input_dir/input_file.txt

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **6. Run MapReduceClient.jar and also provide input and out directories.**

# %%
hadoop jar C:/Hadoop/hadoop-3.1.0/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.1.0.jar wordcount /input_dir /output_dir

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **7. Verify content for generated output file.**

# %%
hadoop dfs -cat /output_dir/*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Some Other usefull commands

# %% [markdown]
# **To leave Safe mode**

# %%
hadoop dfsadmin –safemode leave

# %% [markdown]
# **To Delete file from HDFS directory**

# %%
hadoop fs -rm -r /iutput_dir/input_file.txt

# %% [markdown]
# **To Delete directory from HDFS directory**

# %%
hadoop fs -rm -r /iutput_dir

# %% [markdown]
# ## Verification
# To access information about resource manager current jobs, successful and failed jobs, go to this link in browser- http://localhost:8088/cluster

# %% [markdown]
# ![image.png](attachment:image.png)
