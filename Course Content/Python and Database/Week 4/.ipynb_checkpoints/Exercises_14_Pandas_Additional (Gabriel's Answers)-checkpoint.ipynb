# %% [markdown]
# ## Pandas Lab Exercise (Kaggle Automobile Dataset)
#
# We shall now test your skills in using Pandas package. We will be using the [automobiles Dataset](https://www.kaggle.com/nisargpatel/automobiles/data) from Kaggle. It is also the same `Automobile.csv` dataset from the lecture.
#
# Answer each question asked below w.r.t the automobiles dataset. Load pandas as pd and upload the `Automobile.csv` file as auto

# %%
import pandas as pd

# %%
auto = pd.read_csv('Automobile.csv')

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
# 3      5500       24           30  13950
# 4      5500       18           22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# **How many rows and columns are there?**

# %%
print('no. of rows: ',len(auto))
print('no. of cols: ',len(auto.columns))
# Out:
# no. of rows:  201
# no. of cols:  26

# %% [markdown]
# **What is the average Price of all cars in the dataset?**

# %%
auto["price"].mean()
# Out:
# 13207.129353233831

# %% [markdown]
# **Which is the cheapest make and costliest make of car in the lot?**

# %%
#car_groupedby = auto.groupby("make")
#cheapestMake = car_groupedby["price"].min()
#print(cheapestMake.head(1))
cheapest = auto.sort_values(by='price')
x = cheapest.head(1)
x.iloc[0][-1]
# Out:
# 5118

# %%
costliest = auto.sort_values(by='price', ascending=False)
costliest.head(1)
# Out:
#     symboling  normalized_losses           make fuel_type aspiration  \
# 71          1                140  mercedes-benz       gas        std
#
#    number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 71             two    hardtop          rwd           front       112.0  ...
#
#     engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 71          304         mpfi   3.8    3.35               8.0        184
#
#     peak_rpm city_mpg  highway_mpg  price
# 71      4500       14           16  45400
#
# [1 rows x 26 columns]

# %% [markdown]
# **How many cars have horsepower greater than 100?**

# %%
auto[auto['horsepower'] > 100].describe()
# Out:
#        symboling  normalized_losses  wheel_base      length      width  \
# count  90.000000          90.000000   90.000000   90.000000  90.000000
# mean    1.022222         136.322222  100.722222  180.630000  67.011111
# std     1.557712          32.988874    6.566407   10.769489   2.156643
# min    -2.000000          74.000000   88.600000  157.300000  63.800000
# 25%     0.000000         108.000000   95.900000  173.050000  65.600000
# 50%     1.000000         139.000000   99.600000  178.450000  66.500000
# 75%     3.000000         156.750000  104.300000  188.800000  67.975000
# max     3.000000         231.000000  120.900000  208.100000  72.000000
#
#          height  curb_weight  engine_size       bore     stroke  \
# count  90.00000    90.000000    90.000000  90.000000  90.000000
# mean   53.46000  2898.777778   152.322222   3.456778   3.291000
# std     2.59917   448.959766    48.612392   0.258604   0.330308
# min    47.80000  2128.000000    70.000000   2.540000   2.070000
# 25%    51.60000  2548.750000   121.000000   3.270000   3.127500
# 50%    54.20000  2838.500000   143.000000   3.540000   3.350000
# 75%    55.70000  3092.750000   179.000000   3.620000   3.467500
# max    58.70000  4066.000000   326.000000   3.940000   4.170000
#
#        compression_ratio  horsepower     peak_rpm   city_mpg  highway_mpg  \
# count          90.000000   90.000000    90.000000  90.000000    90.000000
# mean            9.391222  135.655556  5226.111111  20.033333    25.333333
# std             3.143231   31.977928   478.951792   3.128161     3.515615
# min             7.000000  101.000000  4250.000000  13.000000    16.000000
# 25%             8.000000  111.000000  5000.000000  17.250000    23.250000
# 50%             9.000000  121.000000  5225.000000  19.000000    25.000000
# 75%             9.377500  156.000000  5500.000000  23.000000    28.000000
# max            23.000000  262.000000  6600.000000  26.000000    30.000000
#
#               price
# count     90.000000
# mean   18687.022222
# std     8759.655529
# min     7689.000000
# 25%    12941.250000
# 50%    16500.000000
# 75%    21390.000000
# max    45400.000000

# %% [markdown]
# **How many hatchback cars are in the dataset ?**

# %%
auto[auto['body_style']=='hatchback'].count()[0]
# Out:
# 68

# %% [markdown]
# **What are the 3 most commonly found cars in the dataset?**

# %%
auto['make'].value_counts()[:3]
# Out:
# toyota    32
# nissan    18
# mazda     17
# Name: make, dtype: int64

# %% [markdown]
# **Someone purchased a car for 7099, what is the make of the car?**

# %%
x = auto[auto['price']==7099]
x.iloc[0][2]
# Out:
# 'nissan'

# %% [markdown]
# **Which cars are priced greater than 40000?**

# %%
auto[auto['price']>7099]
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# 1               two  convertible          rwd           front        88.6
# 2               two    hatchback          rwd           front        94.5
# 3              four        sedan          fwd           front        99.8
# 4              four        sedan          4wd           front        99.4
# ..              ...          ...          ...             ...         ...
# 196            four        sedan          rwd           front       109.1
# 197            four        sedan          rwd           front       109.1
# 198            four        sedan          rwd           front       109.1
# 199            four        sedan          rwd           front       109.1
# 200            four        sedan          rwd           front       109.1
#
#      ...  engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0    ...          130         mpfi  3.47    2.68               9.0        111
# 1    ...          130         mpfi  3.47    2.68               9.0        111
# 2    ...          152         mpfi  2.68    3.47               9.0        154
# 3    ...          109         mpfi  3.19    3.40              10.0        102
# 4    ...          136         mpfi  3.19    3.40               8.0        115
# ..   ...          ...          ...   ...     ...               ...        ...
# 196  ...          141         mpfi  3.78    3.15               9.5        114
# 197  ...          141         mpfi  3.78    3.15               8.7        160
# 198  ...          173         mpfi  3.58    2.87               8.8        134
# 199  ...          145          idi  3.01    3.40              23.0        106
# 200  ...          141         mpfi  3.78    3.15               9.5        114
#
#      peak_rpm city_mpg  highway_mpg  price
# 0        5000       21           27  13495
# 1        5000       21           27  16500
# 2        5000       19           26  16500
# 3        5500       24           30  13950
# 4        5500       18           22  17450
# ..        ...      ...          ...    ...
# 196      5400       23           28  16845
# 197      5300       19           25  19045
# 198      5500       18           23  21485
# 199      4800       26           27  22470
# 200      5400       19           25  22625
#
# [167 rows x 26 columns]

# %% [markdown]
# **Which are the cars that are both a sedan and priced less than 5000?**

# %%
newauto = auto[(auto['price']<5000) & (auto['body_style']=='sedan')]
newauto
# Out:
# Empty DataFrame
# Columns: [symboling, normalized_losses, make, fuel_type, aspiration, number_of_doors, body_style, drive_wheels, engine_location, wheel_base, length, width, height, curb_weight, engine_type, number_of_cylinders, engine_size, fuel_system, bore, stroke, compression_ratio, horsepower, peak_rpm, city_mpg, highway_mpg, price]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# ### The END
