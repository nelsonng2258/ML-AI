# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

im = mpimg.imread('evermadenhsrainbows1.jpg')
im = np.asarray(im)

plt.imshow(im)
plt.show()

# %%
im = mpimg.imread('evermadenhsrainbows1.jpg')
im = np.asarray(im)
im0 = im[:,:,0]
print(im.shape)
plt.imshow(im0)
plt.show()
# Out:
# (1000, 1500, 3)

# %%
im = mpimg.imread('evermadenhsrainbows1.jpg')
im = np.asarray(im)
im1 = im[:,:,1]
print(im.shape)
plt.imshow(im1)
plt.show()
# Out:
# (1000, 1500, 3)

# %%
im = mpimg.imread('evermadenhsrainbows1.jpg')
im = np.asarray(im)
im2 = im[:,:,2]
print(im.shape)
plt.imshow(im2)
plt.show()
# Out:
# (1000, 1500, 3)

# %%
def rbg_converter(r, g, b, a):
    r = linear_transformation(r, a)
    g = linear_transformation(g, a)
    b = linear_transformation(b, a)
    return np.dstack((r,g,b))

# %%
def linear_transformation(src, a):
    M, N = src.shape
    points = np.mgrid[0:N, 0:M].reshape((2, M*N))
    new_points = np.linalg.inv(a).dot(points).round().astype(int)
    x, y = new_points.reshape((2, M, N), order='F')
    indices = x + N*y
    return np.take(src, indices, mode='wrap')

# %%
#scaling the plane in the x-axis by a factor or 1.5
a = np.array([[1.5, 0],
              [0, 1]])
dst = rbg_converter(im0, im1, im2, a)
plt.imshow(dst)
plt.show()

# %%
#dilating the plane by a factor of 1.8
a = 1.8*np.eye(2)
dst = rbg_converter(im0, im1, im2, a)
plt.imshow(dst)
plt.show()

# %%
#dilating the plane by a factor of 0.5
a = .5*np.eye(2)
dst = rbg_converter(im0, im1, im2, a)
plt.imshow(dst[:500,:750,:])
plt.show()

# %%
#scaling the plane in the y-axis by factor of o.5
a = np.array([[1, 0],
              [0, .5]])
dst = rbg_converter(im0, im1, im2, a)
plt.imshow(dst[:500,:,:])
plt.show()

# %%
#shearing about the y-axis with a vertical displacement of +x/2
a = np.array([[1, 0],
              [.5, 1]])
dst = rbg_converter(im0, im1, im2, a)
plt.imshow(dst)
plt.show()

# %%
#rotate through 45 degre about the origin
alpha = np.pi/4
a = np.array([[np.cos(alpha), -np.sin(alpha)],
              [np.sin(alpha), np.cos(alpha)]])
dst = rbg_converter(im0, im1, im2, a)
plt.imshow(dst)
plt.show()

# %%
#relextion in a line with inclination of 45 degree through the origin
alpha = np.pi/4
a = np.array([[np.cos(2*alpha), np.sin(2*alpha)],
              [np.sin(2*alpha), -np.cos(2*alpha)]])
dst = rbg_converter(im0, im1, im2, a)
plt.imshow(dst[:,:1000,:])
plt.show()

# %%
plt.imshow(np.rot90(im))
plt.show()

# %%
plt.imshow(np.fliplr(im))
plt.show()

# %%
plt.imshow(np.flipud(im))
plt.show()
