# %% [markdown]
# # Recap
# ---
#
# ## Regex
#
# * is a special sequence of characters that defines a pattern for a complex string matching.
# * uses the `re` library
# * patterns uses **raw strings**
# * no one pattern to rule them all!
#
#
# ### Exercise

# %% [markdown]
# Write a regular expression to convert dates of the format YYYY-MM-DD to DD-MM-YYYY.
#
# **Program Output Example**
# <pre>
# Enter date in the format YYYY-MM-DD or 'q' to exit: 1985-05-25
# New date: 25-05-1985
# Enter date in the format YYYY-MM-DD or 'q' to exit: 1786-2-1
# New date: 1-2-1786
# Enter date in the format YYYY-MM-DD or 'q' to exit: q
# </pre>

# %%
import re

def change_date_format(dt):
    return re.sub(r'(\d{4})-(\d{1,2})-(\d{1,2})', '\\3-\\2-\\1',dt)

while True:
    date_str = input("Enter date in the format YYYY-MM-DD or 'q' to exit: ")
    
    if date_str == 'q':
        break
    
    print(f'New date: {change_date_format(date_str)}')
# Out:
# Enter date in the format YYYY-MM-DD or 'q' to exit: 1985-05-25
# New date: 25-05-1985
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-f565cdc248d5> in <module>
#       5
#       6 while True:
# ----> 7     date_str = input("Enter date in the format YYYY-MM-DD or 'q' to exit: ")
#       8
#       9     if date_str == 'q':
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Case Study: Web Scraper
#
# **Problem Statement:** We need some method to obtain data legally and freely but how?
#
# ---
#
# ## Topics Covered
# * Legalities
# * Setting up the required libraries
# * HTTP Crash Course
# * HTML Crash Course
# * Stitching it together
# ---

# %% [markdown]
# ## Legalities
#
# Let's say that we want to scrape stock exchange data from websites such as NYC stock exchange or SGX but first we need to answer several questions:
#
# 1. Can we legally do it?
# 2. How do we tell if it's legal or not to scrape the data from the website?
# 3. What are the consequence if the data was illegally obtained?
#
# First and foremost, always **inform and get approval from your direct supervisor** for the sources of data you are going to obtain because of the Singapore Legislation for the **[Computer Misuse Act](https://sso.agc.gov.sg/Act/CMA1993)**.
#
# > **Unauthorised access to computer material**
# 3.—(1)  Subject to subsection (2), any person who knowingly causes a computer to perform any function for the purpose of securing access without authority to any program or data held in any computer shall be guilty of an offence and shall be liable on conviction to a fine not exceeding \\$5,000 or to imprisonment for a term not exceeding 2 years or to both and, in the case of a second or subsequent conviction, to a fine not exceeding \\$10,000 or to imprisonment for a term not exceeding 3 years or to both.
#
# **How do we tell that the data from the webpage is allowable to be scraped?**
# Most websites uses techniques to limit web scraping like CAPTCHA tests or setting password access or use of anti-scraping tools.
#
# | ![captcha.PNG](attachment:captcha.PNG) | ![captcha_2.PNG](attachment:captcha_2.PNG) |
# |:---:|:---:|
# | **Figure 1:** Word captcha | **Figure 2:** Image captcha |
#
# Some websites also have a `robots.txt` file which is accessible from their main website (eg: `http://www.flipkart.com/robots.txt`) that details which parts of the website are allowed to be scraped or indexed. Let's go through the rules of `robots.txt` files.

# %% [markdown]
# #### Robots.txt Rules
#
# 1. **Allow full access**
# <pre>
# User-agent: *
# Disallow:
# </pre>
#
#  This means that all content from this website is allowable to be scraped and used.
#
#
# 2. **Block ALL access**
# <pre>
# User-agent: *
# Disallow:/
# </pre>
#  **DO NOT** scrape or use **any data** from the website or risk legal proceedings.
#
#
# 3. **Partical access**
# <pre>
# User-agent: *
# Disallow: /folder/<br>
# User-agent: *
# Disallow: /file.html
# </pre>
#
#  Webpages with the URL stated in the 'Disallow' section are not to be scraped.
#
#
# 4. **Crawl rate limit**
# ```
# Crawl-delay: 11
# ```
#
#  This is meant for web scrapers or crawlers that does automatic data collection or indexing. The `11` signifies the number of seconds to delay between each scrape. This is to avoid putting unwanted stress on the server thus making the site slow for human visitors.
#
#
# 5. **Visit time**
# ```
# Visit-time: 0400-0845
# ```
#
#  Tells us or the bot when they are able to scrape data. This is mainly used to avoid peak hour data collection or indexing.
#
#
# 6. **Request rate**
# ```
# Request-rate: 1/10
# ```
#
#  Some websites **do not** entertain bots trying to fetch multiple pages simultaneously therefore they limit this behaviour. The value `1/10` means the site allows requests of 1 page every 10 seconds.

# %% [markdown]
# **Example 1: Partial Flipkert's [`robots.txt`](http://www.flipkart.com/robots.txt) file**

# %%
User-agent: Mediapartners-Google
Disallow:

User-agent: Adsbot-Google
Disallow:

User-agent: Googlebot-Image
Disallow:

# cart
User-agent: *
Disallow: /viewcart

# Something related to carousel and recommendation carousel
User-agent: *
Disallow: /dynamic/
...

# %% [markdown]
# **Example 2: Channel News Asia's [`robots.txt`](https://www.channelnewsasia.com/robots.txt) file**

# %%
User-agent: *
Sitemap: https://www.channelnewsasia.com/googlenews/cna_news_sitemap.xml
Sitemap: https://www.channelnewsasia.com/sitemap.xml
Crawl-delay: 10
# Out:
#   File "<ipython-input-4-2c2737b10c36>", line 1
#     User-agent: *
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Example 3: Singapore Stock Exchange's [`robots.txt`](https://www.sgx.com/robots.txt) file**

# %%
# SGX.com V2 robots.txt
# Tested against https://www.google.com/webmasters/tools/robots-testing-tool
# Last Update: 9 December 2019

# Dev and QA entry to Disallow bots and crawlers

# User-agent: *
# Disallow: /

# Below this line is used in Production

# User-agent: Twitterbot
# Disallow: /
# User-agent: Mediapartners-Google
# Disallow: /
User-agent: *
Allow: /
Disallow: /assets/static/e-learning/

# %% [markdown]
# ---
# ## Setting up the required libraries
#
# For this case study, we will be using 2 additional libraries:
# * **[Requests: HTTP for Humans](https://requests.readthedocs.io/en/master/)** - a simple HTTP library that makes HTTP requests.
# * **[Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)** - a Python library used for pulling data out of HTML and XML files.
#
# Installation via `pip` can be done using the command:
# `pip install requests beautifulsoup4`
#
# ---
#
# ## HTTP Crash Course
#
# For the purpose of the 2 libraries that we are going to use, lets go through the very basic of The Internet. A very simple analogy of the internet is a bunch of computers linked together via a network with the ability to communicate with each other. The top-level protocol used for this communication is called the **Hypertext Transfer Protocol (HTTP)**.
#
# ### The Internet
# Consider the scenario of when a URL such as `www.google.com` has been entered into a browser. Several things occur:
# * **DNS Lookup** - The URL goes to a DNS (Domain Name System) server and it turns it into an IP address. This IP address is what you are sending the request to.
#
# ![dns.png](attachment:dns.png)
#
# * **Request/Response Cycle** - This is where the client (your computer) makes a request to a server. That server then processes your request and issues you a response. Note that every request made is **completely independant**.
#
# ![reqresp.png](attachment:reqresp.png)
#
#  Example of a `request` would be:
#  <pre>
#  GET /18_http.html HTTP/2.0
#  </pre>
#
#  Example of a `response` would be:
#  <pre>
#  HTTP/2.0 200 OK
#  Content-Length: 65635
#  Content-Type: html/text
#  ...
#  </pre>
#
# Whenever a request is made, there is always a method attached to it. The main 4 methonds are:
# * **GET** - retrieves data from the server
# * **POST** - submit data to the server
# * **PUT** - update data already on the server
# * **DELETE** - deletes data from the server
#
# On top of those methods, there are also parts like the URL to the server, parameters for authorization or from a form, content length and type, etc all this contained within the HTTP header. Upon receiving a request, the server will return with a response and this response will contain a HTTP status code.
#
# Common HTTP status codes are:
# * **200** - OK
# * **404** - Not found
# * **500** - Internal server error
#
# A list of all HTTP Status Codes can be found [here](https://www.restapitutorial.com/httpstatuscodes.html).
#
# The *Requests: HTTP for Humans* library is a 3rd party Python library used for sending HTTP/1.1 requests extremely easily otherwise we would have to use the built-in `json` and `urllib` libraries to construct a request and process request/response messages to and from servers.
#
# **Example 4: Request message without using the *Requests: HTTP for Humans* library**
#
# ```python
# import json
# import urllib.request
#
# conditionsSetURL = 'http://httpbin.org/post'
# newConditions = {"con1":40, "con2":20, "con3":99, "con4":40, "password":"1234"}
# params = json.dumps(newConditions).encode('utf8')
# req = urllib.request.Request(conditionsSetURL, data=params,
#                              headers={'content-type': 'application/json'})
# response = urllib.request.urlopen(req)
# ```

# %% [markdown]
# ### HTML Crash Course
#
# Every webpage that is displayable on a web browser is created using a language called Hypertext Markup Language (HTML). It can also be assisted by other technologies such as Cascading Style Sheets (CSS) and scripting languages such as JavaScript.
#
# In a nutshell, all data on a webpage are delineate by HTML tags but not all tags comes with a start and end tag. HTML elements are denoted by their start and end tag pairs.
#
# Examples of HTML elements/tag:
# * `<p></p>` - paragraph element
# * `<br>` - line break tag
# * `<div></div>` - division or section element
# * `<hr>` - horizontal line tag
#
# With each start tag, there are a set of global and specific attributes that can be added to them to control its behaviour. These attributes either modify the default functionality of an element/tag type or provides functionality to certain element/tag types unable to function correctly without them. For example, in the figure below, the HTML paragraph element has the attribute `class` added to it. The `class` attribute is used refer to one or more classnames from a CSS.
#
# ![html_struc.png](attachment:c790722c-dca4-4bfb-a70e-46ee105f8a9c.png)
#
# HTML elements can also be nested meaning that some HTML elements can contain any number of other elements within them. For example the `<div>` tag is an element can be used like a container to contain other HTML elements/tags to segregate different sections in a HTML document.
#
# ```html
# <div class="myDiv">
#   <h2>This is a heading in a div element</h2>
#   <p>Here is some <b>bold</b> text.</p>
# </div>
# ```
#
# Placement of HTML elements/tags follow a particular structure called the Document Object Model (DOM). This model has a tree structure where each leaf represents an object that makes up part of the HTML document.
#
# ![dom_model.png](attachment:f66ac901-34f2-4e4d-93fa-405be272cf1c.png)

# %% [markdown]
# ---
# ## Stitching it together
#
# Now that we have a rough idea about robots.txt, HTTP and HTML, we can move on to web scraping. The act of web scraping is to effectively harvest data from websites for research or personal interest. The additional libraries that we will use are *Requests: HTTP for Humans* and *Beautiful Soup*.
#
# Although there are ways to develop automated web scraping, this case study will focus on **manual** web scraping. Occassionally, some website will provide an Application Programming Interfaces (APIs) for you to access their data in a predefined manner instead of jousting with HTML. This is beyond the scope of this case study but more can be read up [here](https://realpython.com/api-integration-in-python/) and [here](https://www.dataquest.io/blog/python-api-tutorial/).
#
# The steps to web scraping are as follows:
#
# 1. Find the URL of the website that you want to scrape
# 2. Check the `robots.txt` file of your chosen website
# 3. Inspect the webpage
# 4. Find the data that you want to extract
# 5. Write the code
# 6. Run the code and extract the data
# 7. Store the data in the required format and medium
#
# Let's use the Channel News Asia website for our web scraper. We will not be scraping the whole website but only the Business related news which is found on the URL `https://www.channelnewsasia.com/news/business`. Our goal is to scrape all the article titles and their elapsed time (in hours) from the time of publishing.
#
# ![web_sc_05.PNG](attachment:web_sc_05.PNG)
#
# Following the steps:
#
# **Steps 1 & 2:** From the above, we have ascertain that every webpage from that website is legally okay to be scraped, the only rule that we have to take note of is that we have to do it with a 10 second delay between each request.
#
# **Steps 3:** We need to find out how the aticles are structured within the webpage, in-order to do this, we need to **inspect** the page. An easy way is to do a rough selection (highlight) of the parts that you want to scrape then either select the `Inspect` menu item from the context menu or press `Ctrl + Shift + I` on the keyboard while the browser is active.
#
# ![web_sc_02.PNG](attachment:web_sc_02.PNG)
#
# This will bring up the inspection window in the browser zooming in to the highlighted HTML elements.
#
# ![web_sc_06.PNG](attachment:web_sc_06.PNG)
#
# **Step 4:** From the HTML elements, find the rough area of where the data is located, the `<div>` element is the main container and the `<a>` and `<time>` element is where the data is at.
#
# ![web_sc_07.PNG](attachment:web_sc_07.PNG)
#
# Do take note of the attributes of the elements.
#
# **Step 5 & 6:** Writing the code. First and for most we have to load the required libraries.

# %%
import requests   # HTTP library for Python
from bs4 import BeautifulSoup   # library for pulling data out of HTML and XML files
from datetime import datetime   # Python's datetime library

# %% [markdown]
# The specified URL is `https://www.channelnewsasia.com/news/business`. Although, we only need the news titles and elapsed time from articles from the Channel News Asia Business page, we will request for the whole webpage and pass this to the the BeautifulSoup object. Make sure that the request return with an `OK` status code before passing to the BeautifulSoup object.
#
# BeautifulSoup object uses a `html.parser` to give BeautifulSoup an idiomatic way of navigating, searching and modifying the HTML parse tree.

# %%
# website url
url = "https://www.channelnewsasia.com/news/business"

page = requests.get(url)

if page.status_code == 200:
    soup = BeautifulSoup(page.text, 'html.parser')
    #print(page.status_code)
else:    
    print(page.status_code)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lte IE 9]><html lang="de" class="no-js old-ie"><![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="" lang="en" navigation-scroll-fix="true"><!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge,chrome=IE7" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Latest business news and headlines - CNA</title>
# <!-- newrelic.browser.inject.type: api -->
# <script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"UgADUl5VGwcHXVVSBwED",licenseKey:"ab7b570406",applicationID:"47940004"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(27),c={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,o.indexOf("dev")!==-1&&(c.dev=!0),o.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&i.on("internal-error",function(t){r(t.stack)}),c.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{l?l-=1:o(c||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,s.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:s.now();i("err",[t,n])}var i=t("handle"),a=t(28),c=t("ee"),s=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",l=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),s.xhrWrappable&&t(14),d=!0)}c.on("fn-start",function(t,e,n){d&&(l+=1)}),c.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),c.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),c.on("internal-error",function(t){i("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){_++,T=g.hash,this[u]=y.now()}function o(){_--,g.hash!==T&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var c="-start",s="-end",f="-body",u="fn"+c,d="fn"+s,p="cb"+c,l="cb"+s,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable){var x=t(10),b=t(11),E=t(8),R=t(6),O=t(13),N=t(7),M=t(14),P=t(9),S=t("ee"),C=S.get("tracer");t(16),y.features.spa=!0;var T,_=0;S.on(u,r),S.on(p,r),S.on(d,o),S.on(l,o),S.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+s,"clearTimeout"+c,u]),M.buffer([u,"new-xhr","send-xhr"+c]),N.buffer([m+c,m+"-done",m+f+c,m+f+s]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+c]),C.buffer([u,"no-"+u]),P.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(M,"send-xhr"+c),a(S,"xhr-resolved"),a(S,"xhr-done"),a(N,m+c),a(N,m+"-done"),a(P,"new-jsonp"),a(P,"jsonp-end"),a(P,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,_>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),c=t(12),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(8),"addEventListener"in window&&t(6);var x=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),o.on(v,function(t,e){var n=t[0];n instanceof x&&i("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,y.now(),this.bstType])}),c.on(m,function(){this.bstStart=y.now()}),c.on(v,function(t,e){i(w,[e,this.bstStart,y.now(),"requestAnimationFrame"])}),o.on(g+l,function(t){this.time=y.now(),this.startPath=location.pathn ...
# <link href="//player.ooyala.com/" rel="dns-prefetch"/>
# <meta content="gcqKpYH6dKkhC5wY6P-YBN9YKjoYiXuPzAGLxnPglWk" name="google-site-verification"/>
# <meta content="C897C7AC0C0688E10CE5A2B45767B86C" name="msvalidate.01"/>
# <link href="https://www.channelnewsasia.com/news/business" rel="canonical">
# <meta content="business news, business, breaking news, news headlines, happening now, happening, trending, trending news, trending now, top stories, videos, channel newsasia, channelnewsasia.com" name="keywords">
# <meta content="business news, business, breaking news, news headlines, happening now, happening, trending, trending news, trending now, top stories, videos, channel newsasia, channelnewsasia.com" name="news_keywords">
# <meta content="Latest business and finance news on the economy, property, banking, finance, markets, forex, SMEs and MNCs in Singapore, Asia and around the world on CNA." name="description"/>
# <meta content="1866941073551235" property="fb:app_id"/>
# <meta content="CNA" property="og:site_name"/>
# <meta content="Business" property="og:title">
# <meta content="https://www.channelnewsasia.com/news/business" property="og:url"><meta content="en_US" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="Latest business and finance news on the economy, property, banking, finance, markets, forex, SMEs and MNCs in Singapore, Asia and around the world on CNA." property="og:description"/>
# <meta content="Latest business and finance news on the economy, property, banking, finance, markets, forex, SMEs and MNCs in Singapore, Asia and around the world on CNA." name="twitter:description"/>
# <meta content="Business" name="twitter:title"/>
# <meta content="https://cna-sg-res.cloudinary.com/image/upload/q_auto,f_auto/image/8695368/16x9/991/557/e9615d3f8fac5a826ae3bfa657aec6ec/or/business.png" property="og:image"/>
# <meta content="https://cna-sg-res.cloudinary.com/image/upload/q_auto,f_auto/image/8695368/16x9/991/557/e9615d3f8fac5a826ae3bfa657aec6ec/or/business.png" name="twitter:image"/>
# <meta content="New Content Item" name="twitter:image:alt"/>
# <link href="https://cna-sg-res.cloudinary.com/image/upload/q_auto,f_auto/image/8695368/16x9/991/557/e9615d3f8fac5a826ae3bfa657aec6ec/or/business.png" rel="image_src"/>
# <meta content="Business" name="cXenseParse:mdc-context"/>
# <!-- favicon and touchicon -->
# <!-- use content based 'apple-touch-icon' favicon links -->
# <link href="/image/8395694/1x1/57/57/755b75f6028a7f36cbbf113727506192/Fd/apple-touch-icon.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/>
# <link href="/image/8395694/1x1/60/60/755b75f6028a7f36cbbf113727506192/Xf/apple-touch-icon.png" rel="apple-touch-icon" sizes="60x60" type="image/png"/>
# <link href="/image/8395694/1x1/72/72/755b75f6028a7f36cbbf113727506192/HC/apple-touch-icon.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/>
# <link href="/image/8395694/1x1/76/76/755b75f6028a7f36cbbf113727506192/Oq/apple-touch-icon.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/>
# <link href="/image/8395694/1x1/114/114/755b75f6028a7f36cbbf113727506192/nv/apple-touch-icon.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/>
# <link href="/image/8395694/1x1/120/120/755b75f6028a7f36cbbf113727506192/lU/apple-touch-icon.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/>
# <link href="/image/8395694/1x1/144/144/755b75f6028a7f36cbbf113727506192/ni/apple-touch-icon.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/>
# <link href="/image/8395694/1x1/152/152/755b75f6028a7f36cbbf113727506192/vB/apple-touch-icon.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/>
# <link href="/image/8395694/1x1/180/180/755b75f6028a7f36cbbf113727506192/ku/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/>
# <!-- use content based 'icon' favicon links -->
# <link href="/image/8395690/1x1/16/16/224268a0a371faf669fa7d24742fcd2/fC/default-favicon.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/image/8395690/1x1/32/32/224268a0a371faf669fa7d24742fcd2/Ac/default-favicon.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/image/8395690/1x1/192/192/224268a0a371faf669fa7d24742fcd2/tP/default-favicon.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/blueprint/cna/img/manifest.json" rel="manifest"/>
# <link color="#ffffff" href="/blueprint/cna/img/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="/blueprint/cna/img/browserconfig.xml" name="msapplication-config">
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/blueprint/cna/img/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/><style>
#     @font-face {
#         font-family: 'LatoSubset';
#         src: url("data:application/x-font-woff;charset=utf-8;base64,...") format('woff');
#         font-weight: 400;
#         font-style: normal;
#         unicode-range: U+65 -U+90, U+97-122;
#     }
# </style>
# <link href="/blueprint/cna/css/styles.css" rel="stylesheet">
# <link href="/blueprint/cna/css/print.css" media="print" rel="stylesheet">
# <!--[if lte IE 9]><link rel="stylesheet" href="/blueprint/cna/css/universal.css" /><![endif]-->
# <!-- repository styles start -->
# <link href="/resources/7469166/0/-163884240/news.css" rel="stylesheet" type="text/css"><!-- repository styles end -->
# <link as="script" href="/blueprint/cna/js/main.js" rel="preload"/>
# <link as="script" href="/resources/7469166/0/-1464767637/news.js" rel="preload"/>
# <link as="script" href="/blueprint/cna/js/vendor/libs.js" rel="preload"/>
# <link as="style" href="/resources/7469166/0/-2123328976/news.css" rel="preload"/>
# <!-- Resolving jQuery using URL -->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js" type="text/javascript"></script>
# <link href="/blueprint/cna/css/bootstrap-grid/bootstrap-grid.css" rel="stylesheet"/>
# <link href="/blueprint/cna/css/cnapack.css" rel="stylesheet"/>
# <link href="/blueprint/cna/css/flickity/flickity.min.css" rel="stylesheet"/>
# <link href="/blueprint/cna/css/ekko-lightbox/ekko-lightbox.css" rel="stylesheet"/>
# <link href="/blueprint/cna/lib/algolia-overlay/css/styleguide.css" rel="stylesheet"/>
# <link href="/blueprint/cna/lib/algolia-overlay/css/font-faces.css" rel="stylesheet"/>
# <link href="/blueprint/cna/lib/algolia-overlay/css/app-deps.css" rel="stylesheet"/>
# <link href="/blueprint/cna/lib/algolia-overlay/css/app.css" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.11.2/css/fontawesome.min.css" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.11.2/css/solid.min.css" rel="stylesheet"/>
# <script src="/blueprint/cna/js/js-cookie/js.cookie.min.js"></script>
# <script src="/blueprint/cna/js/cnapack.js"></script>
# <script src="/blueprint/cna/js/meradioPlayer.js"></script>
# <script src="/blueprint/cna/js/flickity/flickity.pkgd.min.js"></script>
# <script src="/blueprint/cna/js/inview/in-view.min.js"></script>
# <script src="/blueprint/cna/js/jquery/dropkick.js"></script>
# <script src="/blueprint/cna/js/jquery/jquery.validate.min.js"></script>
# <script src="/blueprint/cna/lib/algolia-overlay/js/app-deps.js"></script>
# <script src="/blueprint/cna/lib/algolia-overlay/js/app.js"></script>
# <script src="/blueprint/cna/js/brandstudio/ekko-lightbox.min.js"></script>
# <script>
#     // Initialize CNA Facebook utility
#     CnaFb.configure({
#         appId: '1866941073551235',
#         version: 'v3.1',
#         xfbml: true,
#         autoLogAppEvents: true,
#         language: 'en_US',
#         timeout: 0,
#         debug: false,
#         parseOnce: false,
#         parseAll: false
#     });
#
#     // Algolia
#
#         function initializeCm8Algolia() {
#           if(window.cm8Algolia !== undefined && window.cm8Algolia !== null){
#             return;
#           }
#
#           window.cm8Algolia = new Cm8Algolia({
#             element: "#cm8-algolia",
#             app: {
#               onShow: {
#                 animation: "fadeIn"
#               },
#               onHide: {
#                 animation: "fadeOut"
#               },
#               categories: {"Cna-Current-Affairs-Podcasts":"CNA Current Affairs Podcasts","cna-current-affairs-podcasts":"CNA Current Affairs Podcasts","cna":"CNA"},
#               categoryUrlMap: [],
#               durationBeforeClose: 1300
#             },
#             news: {
#               latest: {
#                 max: 20,
#               },
#               endpoint: {
#                 latest: "/blueprint/servlet/syndication/v1/news/json/8395986?limit=10"
#               },
#               defaultImage: "/blueprint/cna/lib/algolia-overlay/images/cna-img.jpg"
#             },
#             search:  {
#               placeholder: "Search keywords or topics",
#               minChars: 1,
#               recent: {
#                 max: 5,
#                 hideOnEmpty: false
#               },
#               querySuggestion: {
#                 max: 10,
#                 medium: 5,
#                 small: 3
#               },
#               suggestion: {
#                 max: 10,
#                 medium: 5,
#                 small: 3
#               },
#               applicationId: "KKWFBQ38XF",
#               searchApiKey: "504d2f0996dac6611337bfcde2392960",
#               result: {
#                 page: "/blueprint/servlet/action/news/8396414/search",
#                 criteriaName: "q",
#                 actionUrl: "/action/news/8396414/search?q={criteria}&page=0"
#               },
#               indices: {
#                 data: "cna-EZrqV5Hx",
#                 suggestion: "cna-qs-EZrqV5Hx",
#               },
#               badwordFilters: []
#             },
#             trending: {
#               topics: {
#                 actionUrl: "/news/topic/{topic}",
#                 max: 10,
#                 items: ["COVID-19","US election","Donald Trump","Joe Biden","Mahathir Mohamad","China","Malaysia","Lee Hsien Loong","Parti Liyani","Muhyiddin Yassin","Joe Biden","Brexit","Xi Jinping","Indonesia","earthquakes","PAP","Jewel Changi Airport","Traffic accidents","Yishun","Crime","Offbeat","Terrorism","1MDB","North Korea","Thailand","Philippines","Myanmar","Vietnam"]
#               }
#             },
#             share: {
#               menu: false,
#               list: ["whatsapp","facebook","twitter","email","linkedin"]
#             },
#             bookmark: {
#               show: false
#             }
#           });
#         }
#
#
#     $(document).ready(function(){
#         CnaFb.initializeSdk();
#
#         var mainCarousel = $('.main-carousel');
#
#         if(mainCarousel.length > 0){
#             mainCarousel.flickity({
#                 cellAlign: 'center',
#                 wrapAround: false,
#                 watchCSS: true,
#                 initialIndex: 0
#             });
#         }
#
#         // Configure MeRadio Live Stream
#         if(window.MeRadio !== undefined){
#           MeRadio.configure({
#  'width':42,
#  'height':33,
#  'top':50,
#  'left':50,
#  'toolbar':false,
#  'menubar':false,
#  'resizable':false,
#  'url':'https://live.melisten.sg/liveradio/cna938?embedded=cna938'
# });
#         }
#
#         // Algolia
#
#             $('.meta-navigation__main-list-link.is-search').click(function(evt){
#                 evt.preventDefault();
#                 initializeCm8Algolia();
#                 window.cm8Algolia.showSearch();
#             });
#
#             $('.header__article-bar-search-link').click(function(evt){
#               evt.preventDefault();
#               initializeCm8Algolia();
#               window.cm8Algolia.showSearch();
#             });
#
#
#
#         // Algolia search
#
#
#         // MeRewards
#
#             if(window.MeRewards !== null && window.MeRewards !== undefined){
#               window.meRewards = new MeRewards({
#                 useToken: true
#               });
#               meRewards.watchPanel();
#             }
#
#
#     });
# </script>
# <meta content="1285f55cdd81527b7b36a87605b70f" name="pocket-site-verification">
# <style>
# li.nav-sections__list-item.is-background-01 {
# margin-right: 0px;
# }
#
#
# @media screen and (min-width:992px){
#
#
# li.nav-sections__list-item.lifestyle-slant a:hover {
# text-decoration: underline;
# }
#
#
#     .c-button-main-nav--close-desktop::before {
#
#     border-color: transparent transparent transparent #a12528;
#     background: #541317;
# }
#
#     .nav-primary__top-navigation ul li:last-child {
#     top: -2px;
#     position: relative;
# }
#     [data-css=c-header] .header__outer.is-region-02 .c-button-main-nav--default::before {
#     background: #541317;
# }
# .c-nav-sections--main-navigation .nav-sections__list-item-link {
#     font-size: 0.8625rem;
#     padding-left: 10px;
#     padding-right: 10px;
# }
#
# }
# [data-css=c-nav-primary] .nav-primary__region.is-region-01 {
#     background-color: #541317;
# }
# [data-css=c-nav-sections] .nav-sections__list-item.is-background-01 {
#     background-color: #541317;
#     }
# .c-button-main-nav--close-desktop, .c-button-main-nav--close-desktop .button-main-nav__button{
#        background: #541317 !important;
#     }
# .header__outer.is-region-02 {
#     background: #541317 !important;
# }
# [data-css=c-header] .header__inner {
#     max-width: 1280px;
# }
# [data-css=c-nav-primary] .nav-primary__wrapper {
#     flex-flow: row wrap;
#     max-width: 1280px;
# }
# li.lifestyle-slant.nav-sections__list-item{
#     display:block;
# }
# li.nav-sections__list-item.lifestyle-slant a {
#     white-space: nowrap;
# }
# li.nav-sections__list-item.lifestyle-slant {
#     margin-right: 40px;
#     background: #a50007;
#     height: 62px;
#     top: -1px;
#     position: relative;
# }
# li.nav-sections__list-item.lifestyle-slant >a:after {
#     content: '';
#     position: absolute;
#      border-style: solid;
#     border-width: 0 40px 62px 0;
#     border-color: transparent transparent #a50007 transparent;
#     left: 100%;
#     top: -23px;
#     z-index: 1;
# }
#
#
# li.nav-sections__list-item.lifestyle-slant > a {
#     position: relative;
#     text-decoration: none;
#     display: block;
#     position: relative;
#     top: 23px;
# }
# li.nav-sections__list-item.lifestyle-slant > a:before {
#     content: '';
#     position: absolute;
#     width: 0;
#     height: 0;
#     left: -40px;
#     border-style: solid;
#     border-width: 0 40px 62px 0;
#     border-color: transparent #a50007 transparent transparent;
#     top: -24px;
# }
# li.nav-sections__list-item.lifestyle-slant.insider {
#     background: #6b040d;
# }
#
# li.nav-sections__list-item.lifestyle-slant.insider > a:before {
#      border-color: transparent #6b040d transparent transparent;
# }
#
# li.nav-sections__list-item.lifestyle-slant.insider > a:after {
#     border-color: transparent transparent #6b040d #6b040d;
# }
#
# li.nav-sections__list-item {
#     margin-right: 7px;
# }
#
# @media screen and (max-width:767px){
#
# .c-nav-sections--main-navigation .nav-sections__list-item:last-child {
#     margin-left: -20px !important;
#     width: 110%;
# }
#     .c-nav-sections--main-navigation .nav-sections__list-item:last-child {
#     background-color: #541317;
#     margin-left: 0px;
# }
#     .c-nav-sections--main-navigation .nav-sections__list-item:last-child .nav-sections__list-item-link {
#     border: none;
#     left: 25px;
#     position: relative;
# }
#
#     [data-css=c-nav-primary] .nav-primary__region.is-region-01{
# background-color: #671e20;
#     }
#     li.nav-sections__list-item.lifestyle-slant {
#     display: block;
#     width: 110%;
#     left: -14px;
#     position: relative;
# }
# li.nav-sections__list-item.lifestyle-slant a {
#     left: 20px;
# }
#     li.nav-sections__list-item.lifestyle-slant >a:after {
#     content: '';
#     position: absolute;
#     border-style: solid;
#     border-width: 0;
#     border-color: transparent transparent transparent transparent;
#     left: 100%;
#     top: 0px;
#     z-index: 0;
# }
#
#     li.nav-sections__list-item.lifestyle-slant > a {
#     top: 0px;
# }
#
#     li.nav-sections__list-item.lifestyle-slant {
#     margin-right: 0px;
#     top: 0px;
# }
#
# li.nav-sections__list-item.lifestyle-slant > a:before {
#     content: '';
#     position: relative;
#     width: 0;
#     height: 0;
#     left: 0px;
#     border-style: solid;
#     border-width: 0px;
#     top: 0px !important;
# }
# }
#
# .c-nav-sections--main-navigation .nav-sections__list-item-link {
#        font-size: 15px;
#     font-size: .9375rem;
# }
#
# li.nav-sections__list-item.lifestyle-slant a {
#     padding-left: 0px;
#     padding-right: 0px;
# }
#
#
# @media screen and (min-width: 768px) and (max-width: 992px){
# [data-css=c-nav-sections] .nav-sections__list-item.is-background-01 {
#     padding: 21px 41px;
# }
#
# li.nav-sections__list-item {
#     margin-right: 0px;
# }
# }
# @media screen and (min-width: 1279px) and (max-width: 1365px){
#
#
#     [data-css="c-header"] .header__inner {
#     max-width: 1170px;
# }
# [data-css="c-nav-primary"] .nav-primary__wrapper {
#     max-width: 1170px;
# }
# }
#
#
# span.meta-navigation__icon.i-cna-938 svg {
#     left: -3px;
# }
# [data-css=c-meta-navigation] span.meta-navigation__icon.i-watch-tv svg {
#     position: relative;
#     left: -8px;
#     top: 32px;
# }
#
#
#
# .c-nav-sections--main-navigation .nav-sections__list-item-link .nav-sections__list-item-icon.i-cna-938 svg {
# cursor: pointer;
# filter: brightness(0) invert(1);
# }
#
#
# .c-nav-sections--main-navigation .nav-sections__list-item-link .nav-sections__list-item-icon.i-watch-tv svg {
# cursor: pointer;
# filter: brightness(0) invert(1);
# }
#
#
# .c-nav-sections--main-navigation .nav-sections__list-item-link .nav-sections__list-item-icon.i-watch-tv svg {
# position: relative;
# top: 2px;
# left: 3px;
# }
#
#
#
#
# .c-nav-sections--main-navigation .nav-sections__list-item-link .nav-sections__list-item-icon.i-watch-tv {
#     padding-left: 0px;
#     margin-right: 10px;
# }
#
# .c-nav-sections--main-navigation .nav-sections__list-item-link .nav-sections__list-item-icon.i-cna-938 {
#     padding-left: 0px;
#     margin-right: 5px;
# }
# .c-nav-sections--main-navigation .nav-sections__list-item-link .nav-sections__list-item-icon.i-cna-938 svg {
#     top: 5px;
#     position: relative;
# }
#
# .c-nav-sections--main-navigation .nav-sections__list-item-link .nav-sections__list-item-icon.i-watch-tv svg {
#     position: relative;
#     top: 2px;
# }
#
# @media screen and (max-width: 767px){
# .c-nav-sections--main-navigation .nav-sections__list-item-link .nav-sections__list-item-icon.i-watch-tv {
#     margin-right: 10px;
# }
# .c-nav-sections--main-navigation .nav-sections__list-item-link .nav-sections__list-item-icon.i-cna-938 {
#     margin-right: 7px;
# }
# [data-css=c-nav-primary] .nav-primary__region.is-region-02 {
#     top: 0px;
# }
# }
#
#
# @media screen and (max-width: 767px){
#
#
# .c-nav-sections--main-navigation .nav-sections__list li:nth-child(5) {
# border-bottom: 0px !important;
# border: none;
# }
# }
#
#
# @media screen and (min-width: 992px){
# .nav-primary__top-navigation ul li:last-child
# {
# top: 0px !important;
# position: relative;
# }
# }
#
#
# li.nav-sections__list-item.lifestyle-slant.ninethree-eight {
# background: #bd0d14;
# }
#
#
# li.nav-sections__list-item.lifestyle-slant.ninethree-eight > a:before {
#     border-color: transparent #bd0d14 transparent transparent;
# }
# li.nav-sections__list-item.lifestyle-slant.ninethree-eight > a:after {
#     border-color: transparent transparent #bd0d14 transparent;
# }
#
#
#
#
#
#
#
#
# </style>
# <script type="application/ld+json">
# {
#  "@context": "http://schema.org/",
#  "@type": "WebSite",
#  "name": "CNA",
#  "url": "https://www.channelnewsasia.com/",
#  "potentialAction": {
#    "@type": "SearchAction",
#    "target": "https://www.channelnewsasia.com/action/news/8396414/search?query={search_term_string}",
#    "query-input": "required name=search_term_string"
#  }
# }
# </script>
# <script type="application/ld+json">
# {
#  "@context": "http://schema.org",
#  "@type": "NewsMediaOrganization",
#  "name": "CNA",
#  "url": "https://www.channelnewsasia.com",
#  "logo": "https://www.channelnewsasia.com/blob/8396140/9e24274cb1be2c905593bba3db240fb9/cna-logo-data.jpg",
#  "contactPoint": {
#    "@type": "ContactPoint",
#    "telephone": "+6582188281",
#    "contactType": "customer service",
#    "areaServed": "SG",
#    "availableLanguage": "English"
#  },
#  "sameAs": [
#    "https://www.facebook.com/ChannelNewsAsia/",
#    "https://twitter.com/ChannelNewsAsia",
#    "https://plus.google.com/u/0/117055544942915186224",
#    "https://www.instagram.com/channelnewsasia/",
#    "https://www.youtube.com/user/channelnewsasia",
#    "https://en.wikipedia.org/wiki/Channel_NewsAsia",
#    "https://t.me/cnalatest"
#  ]
# }
# </script>
# <script type="application/ld+json">
# {
#  "@context": "http://schema.org",
#  "@type": "Organization",
#  "url": "https://www.channelnewsasia.com",
#  "logo": "https://www.channelnewsasia.com/blob/8396140/9e24274cb1be2c905593bba3db240fb9/cna-logo-data.jpg",
#  "contactPoint": [{
#    "@type": "ContactPoint",
#    "telephone": "+6582188281",
#    "contactType": "customer service"
#  }]
# }
# </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-TR3KMM');</script>
# <!-- End Google Tag Manager -->
# <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5e0028e53cd1fd98" type="text/javascript"></script>
# <!--Check if  page internationalization switching is enabled-->
# <script>
#         // Use for home page switching
#         var MCHomeSwitch=(function(){var C=this;var n="#home-switcher";var p=window.location.protocol==="https:"?"https":"http";var y="prd";var z=30;var x="cna_default_country";var k=false;var q=false;var i=false;var s={dev:["dev.channelnewsasia.com","dev.channelnewsasia.com/news",],stg:["beta.www.channelnewsasia.com","beta.www.channelnewsasia.com/news","beta-www.channelnewsasia.com","beta-www.channelnewsasia.com/news",],prd:["www.channelnewsasia.com","www.channelnewsasia.com/news","channelnewsasia.com","channelnewsasia.com/news",],localhost:["localhost:40081/blueprint/servlet/page/news"]};var o={dev:[{code:"SG",url:"dev.channelnewsasia.com",},{code:"default",url:"dev.channelnewsasia.com/news/international"}],stg:[{code:"SG",url:"beta-www.channelnewsasia.com",},{code:"default",url:"beta-www.channelnewsasia.com/news/international"}],prd:[{code:"SG",url:"www.channelnewsasia.com",},{code:"default",url:"www.channelnewsasia.com/news/international"}],localhost:[{code:"SG",url:"localhost:40081/blueprint/servlet/page/news",},{code:"default",url:"localhost:40081/blueprint/servlet/page/news/international"}]};var u={localhost:{url:"//localhost:40081/blueprint/servlet/countryCode"},dev:{url:"//dev.channelnewsasia.com/blueprint/servlet/countryCode"},stg:{url:"//beta-www.channelnewsasia.com/blueprint/servlet/countryCode"},prd:{url:"//www.channelnewsasia.com/blueprint/servlet/countryCode"}};function d(){i=true;c("Init MCHomeSwitcher");E()}function E(){window.MCHomeSwitcher=this;var H=window.location.protocol==="https:"?"https":"http";var G=v("homeswitch.default");var F=v("homeswitch.enabled",{mustBe:"false","default":true});k=v("homeswitch.simulate",{mustBe:"true","default":false});p=v("homeswitch.scheme",{"default":H});q=v("homeswitch.verbose",{mustBe:"true","default":false});geolocation=v("homeswitch.geolocation");c("INFO: HomeSwitcher config");c({currentUrl:window.location.href,defaultCountry:G,isEnabled:F,simulate:k,scheme:p,verbose:q});if(G!=null&&G!==""){D(G)}if(F){A()}else{c("INFO: Homeswitch is disabled. Use homeswitch.enabled as query param to enable/disable.")}}function h(F){var G=window.location.href;var I=new RegExp("[?&]("+F+"=[a-zA-Z0-9\\_\\.]+)","g");var H=I.exec(G);if(H===null||H.length===0){return null}return H[1]}function v(F,I){var H=(typeof I!=="undefined"&&typeof I["default"]!=="undefined")?I["default"]:null;var J=(typeof I!=="undefined"&&typeof I.mustBe!=="undefined")?I.mustBe:null;var G=h(F);if(J!==null){if(G!==null&&G===J){return G}return H}return(G!==null&&G!=="")?G:H}function c(F){if(q||a()==="dev"||a()==="localhost"){console.info(F)}}function a(){var F=window.location.hostname;switch(F){case"localhost":return"localhost";case"dev.channelnewsasia.com":return"dev";case"beta-www.channelnewsasia.com":return"stg";default:return"prd"}}function B(){return window.location.href.split(/[?#]/)[0]}function m(G){var F=o[a()].filter(function(H){if(H.code.toLowerCase()===G.toLowerCase()){return true}return false});if(F.length==0){return null}return{url:p+"://"+F[0].url,code:F[0].code}}function j(){var H=B();var G=p;var F=o[a()].filter(function(J){var I=G+"://"+J.url;var K=I+"/";return((H===I)||(H===K))?true:false});if(F.length>=1){return true}return false}function e(){var H=B();var G=p;var F=s[a()].filter(function(J){var I=G+"://"+J;var K=I+"/";return((H===I)||(H===K))?true:false});if(F.length>=1){return true}return false}function g(F){if(!F.successful){c("WARNING: Geolocation API failed.");return}var H=m(F.country);if(H===null){c("WARNING: Could not identify destination to route. Will be using default home URL");H=m("default")}if(H===null){c("WARNING: No default route specified.");return}c("INFO: ROUTER INFO:");c(H);var G=w(x);if(G===null){G=H.code;D(G)}else{c("INFO: User already have default home page stored:"+G)}c("INFO: Getting stored home page: "+G);var I=m(G);if(I===null){c("INFO: No stored home page for "+G+". Using default");I=m("default")}c("INFO: Checking of current url "+B()+" is equals to destination "+I.url);if(b(B(), ...
#         MCHomeSwitch.switchHome();
#     </script>
# <script>
#
#     /*! CSS.supports() Polyfill
#     * https://gist.github.com/codler/03a0995195aa2859465f
#     * Copyright (c) 2014 Han Lin Yap http://yap.nu; MIT license */
#     "CSS"in window||(window.CSS={}),"supports"in window.CSS||(window.CSS._cacheSupports={},window.CSS.supports=function(n,e){function r(n,e){function r(n,e){var r=n.split(e);return r.length>1?r.map(function(n,e,r){return e%2==0?n+r[e+1]:""}).filter(Boolean):void 0}var t=document.createElement("div").style;if("undefined"==typeof e){var o=r(n,/([)])\s*or\s*([(])/gi);if(o)return o.some(function(n){return window.CSS.supports(n)});var i=r(n,/([)])\s*and\s*([(])/gi);if(i)return i.every(function(n){return window.CSS.supports(n)});t.cssText=n.replace("(","").replace(/[)]$/,"")}else t.cssText=n+":"+e;return!!t.length}var t=[n,e].toString();return t in window.CSS._cacheSupports?window.CSS._cacheSupports[t]:window.CSS._cacheSupports[t]=r(n,e)});
# </script>
# <!-- Load webfonts in head to prevent FOIT and FOUT -->
# <script>
#     (function() {
#
#         // Optimization for Repeat Views
#         if( sessionStorage.criticalFoftDataUriFontsLoaded ) {
#             document.documentElement.className += " is-font-bundle-1-loaded is-font-bundle-2-loaded";
#             return;
#         }
#
#         // promise polyfill
#         (function(){'use strict';var f,g=[];function l(a){g.push(a);1==g.length&&f()}function m(){for(;g.length;)g[0](),g.shift()}f=function(){setTimeout(m)};function n(a){this.a=p;this.b=void 0;this.f=[];var b=this;try{a(function(a){q(b,a)},function(a){r(b,a)})}catch(c){r(b,c)}}var p=2;function t(a){return new n(function(b,c){c(a)})}function u(a){return new n(function(b){b(a)})}function q(a,b){if(a.a==p){if(b==a)throw new TypeError;var c=!1;try{var d=b&&b.then;if(null!=b&&"object"==typeof b&&"function"==typeof d){d.call(b,function(b){c||q(a,b);c=!0},function(b){c||r(a,b);c=!0});return}}catch(e){c||r(a,e);return}a.a=0;a.b=b;v(a)}}
#             function r(a,b){if(a.a==p){if(b==a)throw new TypeError;a.a=1;a.b=b;v(a)}}function v(a){l(function(){if(a.a!=p)for(;a.f.length;){var b=a.f.shift(),c=b[0],d=b[1],e=b[2],b=b[3];try{0==a.a?"function"==typeof c?e(c.call(void 0,a.b)):e(a.b):1==a.a&&("function"==typeof d?e(d.call(void 0,a.b)):b(a.b))}catch(h){b(h)}}})}n.prototype.g=function(a){return this.c(void 0,a)};n.prototype.c=function(a,b){var c=this;return new n(function(d,e){c.f.push([a,b,d,e]);v(c)})};
#             function w(a){return new n(function(b,c){function d(c){return function(d){h[c]=d;e+=1;e==a.length&&b(h)}}var e=0,h=[];0==a.length&&b(h);for(var k=0;k<a.length;k+=1)u(a[k]).c(d(k),c)})}function x(a){return new n(function(b,c){for(var d=0;d<a.length;d+=1)u(a[d]).c(b,c)})};window.Promise||(window.Promise=n,window.Promise.resolve=u,window.Promise.reject=t,window.Promise.race=x,window.Promise.all=w,window.Promise.prototype.then=n.prototype.c,window.Promise.prototype["catch"]=n.prototype.g);}());
#
#         // FontFaceObserver https://github.com/bramstein/fontfaceobserver
#         (function(){function l(a,b){document.addEventListener?a.addEventListener("scroll",b,!1):a.attachEvent("scroll",b)}function m(a){document.body?a():document.addEventListener?document.addEventListener("DOMContentLoaded",function c(){document.removeEventListener("DOMContentLoaded",c);a()}):document.attachEvent("onreadystatechange",function k(){if("interactive"==document.readyState||"complete"==document.readyState)document.detachEvent("onreadystatechange",k),a()})};function q(a){this.a=document.createElement("div");this.a.setAttribute("aria-hidden","true");this.a.appendChild(document.createTextNode(a));this.b=document.createElement("span");this.c=document.createElement("span");this.h=document.createElement("span");this.f=document.createElement("span");this.g=-1;this.b.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";this.c.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";
#             this.f.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";this.h.style.cssText="display:inline-block;width:200%;height:200%;font-size:16px;max-width:none;";this.b.appendChild(this.h);this.c.appendChild(this.f);this.a.appendChild(this.b);this.a.appendChild(this.c)}
#             function w(a,b){a.a.style.cssText="max-width:none;min-width:20px;min-height:20px;display:inline-block;overflow:hidden;position:absolute;width:auto;margin:0;padding:0;top:-999px;left:-999px;white-space:nowrap;font:"+b+";"}function x(a){var b=a.a.offsetWidth,c=b+100;a.f.style.width=c+"px";a.c.scrollLeft=c;a.b.scrollLeft=a.b.scrollWidth+100;return a.g!==b?(a.g=b,!0):!1}function z(a,b){function c(){var a=k;x(a)&&null!==a.a.parentNode&&b(a.g)}var k=a;l(a.b,c);l(a.c,c);x(a)};function A(a,b){var c=b||{};this.family=a;this.style=c.style||"normal";this.weight=c.weight||"normal";this.stretch=c.stretch||"normal"}var B=null,C=null,D=null;function H(){if(null===C){var a=document.createElement("div");try{a.style.font="condensed 100px sans-serif"}catch(b){}C=""!==a.style.font}return C}function I(a,b){return[a.style,a.weight,H()?a.stretch:"","100px",b].join(" ")}
#             A.prototype.load=function(a,b){var c=this,k=a||"BESbswy",y=b||3E3,E=(new Date).getTime();return new Promise(function(a,b){null===D&&(D=!!window.FontFace);if(D){var J=new Promise(function(a,b){function e(){(new Date).getTime()-E>=y?b():document.fonts.load(I(c,c.family),k).then(function(c){1<=c.length?a():setTimeout(e,25)},function(){b()})}e()}),K=new Promise(function(a,c){setTimeout(c,y)});Promise.race([K,J]).then(function(){a(c)},function(){b(c)})}else m(function(){function r(){var b;if(b=-1!=f&&
#                             -1!=g||-1!=f&&-1!=h||-1!=g&&-1!=h)(b=f!=g&&f!=h&&g!=h)||(null===B&&(b=/AppleWebKit\/([0-9]+)(?:\.([0-9]+))/.exec(window.navigator.userAgent),B=!!b&&(536>parseInt(b[1],10)||536===parseInt(b[1],10)&&11>=parseInt(b[2],10))),b=B&&(f==t&&g==t&&h==t||f==u&&g==u&&h==u||f==v&&g==v&&h==v)),b=!b;b&&(null!==d.parentNode&&d.parentNode.removeChild(d),clearTimeout(G),a(c))}function F(){if((new Date).getTime()-E>=y)null!==d.parentNode&&d.parentNode.removeChild(d),b(c);else{var a=document.hidden;if(!0===a||void 0===
#                     a)f=e.a.offsetWidth,g=n.a.offsetWidth,h=p.a.offsetWidth,r();G=setTimeout(F,50)}}var e=new q(k),n=new q(k),p=new q(k),f=-1,g=-1,h=-1,t=-1,u=-1,v=-1,d=document.createElement("div"),G=0;d.dir="ltr";w(e,I(c,"sans-serif"));w(n,I(c,"serif"));w(p,I(c,"monospace"));d.appendChild(e.a);d.appendChild(n.a);d.appendChild(p.a);document.body.appendChild(d);t=e.a.offsetWidth;u=n.a.offsetWidth;v=p.a.offsetWidth;F();z(e,function(a){f=a;r()});w(e,I(c,'"'+c.family+'",sans-serif'));z(n,function(a){g=a;r()});w(n,I(c,'"'+
#                     c.family+'",serif'));z(p,function(a){h=a;r()});w(p,I(c,'"'+c.family+'",monospace'))})})};"undefined"!==typeof module?module.exports=A:(window.FontFaceObserver=A,window.FontFaceObserver.prototype.load=A.prototype.load);}());
#
#         var latoSubset = new FontFaceObserver('LatoSubset');
#
#         Promise.all([latoSubset.load()]).then(function () {
#             document.documentElement.className += ' is-font-bundle-1-loaded';
#
#             var lato300 = new FontFaceObserver('Lato', {
#                 weight: 300
#             });
#             var lato400 = new FontFaceObserver('Lato', {
#                 weight: 400
#             });
#             var lato400i = new FontFaceObserver('Lato', {
#                 weight: 400,
#                 style: 'italic'
#             });
#             var lato700 = new FontFaceObserver('Lato', {
#                 weight: 700
#             });
#             var lato700i = new FontFaceObserver('Lato', {
#                 weight: 700,
#                 style: 'italic'
#             });
#             var lato900 = new FontFaceObserver('Lato', {
#                 weight: 900
#             });
#
#             var merriweather300 = new FontFaceObserver('Merriweather', {
#                 weight: 300
#             });
#             var merriweather300i = new FontFaceObserver('Merriweather', {
#                 weight: 300,
#                 style: 'italic'
#             });
#             var merriweather400 = new FontFaceObserver('Merriweather', {
#                 weight: 400
#             });
#             var merriweather400i = new FontFaceObserver('Merriweather', {
#                 weight: 400,
#                 style: 'italic'
#             });
#             var merriweather700i = new FontFaceObserver('Merriweather', {
#                 weight: 700,
#                 style: 'italic'
#             });
#             var effra700 = new FontFaceObserver('Effra', {
#                 weight: 700,
#                 style: 'normal'
#             });
#             var effra400 = new FontFaceObserver('Effra', {
#                 weight: 400,
#                 style: 'normal'
#             });
#
#
#             Promise.all([
#                 lato300.load(),
#                 lato400.load(),
#                 lato400i.load(),
#                 lato700.load(),
#                 lato700i.load(),
#                 lato900.load(),
#                 merriweather300.load(),
#                 merriweather300i.load(),
#                 merriweather400.load(),
#                 merriweather400i.load(),
#                 merriweather700i.load(),
#                 effra700.load(),
#                 effra400.load()
#             ]).then(function () {
#                 document.documentElement.className += ' is-font-bundle-2-loaded';
#
#                 // Optimization for Repeat Views
#                 sessionStorage.criticalFoftDataUriFontsLoaded = true;
#             });
#         });
#     })();
# </script>
# <script>
#     var adSection = 'business_landing';
# </script><script>
#     window.App = {};
#     window.App.consoleLog = false;
# </script>
# <script>
#     var isCompactDocument = true;
#     var compactLayoutCookie = decodeURIComponent(document.cookie.replace(new RegExp("(?:(?:^|.*;)\\s*" + encodeURIComponent('compactlayout').replace(/[\-\.\+\*]/g, "\$&") + "\\s*\\=\\s*([^;]*).*$)|^.*$"), "$1")) || null;
#     if(compactLayoutCookie && isCompactDocument) {
#         window.App.isCompactLayout = true;
#         document.querySelector('html').classList.add('is-compact-layout');
#     }
# </script>
# <!-- Inline grunticon loader and load icons -->
# <script>
#     /*! grunt-grunticon Stylesheet Loader - v2.1.6 | https://github.com/filamentgroup/grunticon | (c) 2015 Scott Jehl, Filament Group, Inc. | MIT license. */
#     !function(){function e(e,n,t){"use strict";var o=window.document.createElement("link"),r=n||window.document.getElementsByTagName("script")[0],a=window.document.styleSheets;return o.rel="stylesheet",o.href=e,o.media="only x",r.parentNode.insertBefore(o,r),o.onloadcssdefined=function(e){for(var n,t=0;t<a.length;t++)a[t].href&&a[t].href===o.href&&(n=!0);n?e():setTimeout(function(){o.onloadcssdefined(e)})},o.onloadcssdefined(function(){o.media=t||"all"}),o}function n(e,n){e.onload=function(){e.onload=null,n&&n.call(e)},"isApplicationInstalled"in navigator&&"onloadcssdefined"in e&&e.onloadcssdefined(n)}!function(t){var o=function(r,a){"use strict";if(r&&3===r.length){var i=t.navigator,c=t.document,s=t.Image,d=!(!c.createElementNS||!c.createElementNS("http://www.w3.org/2000/svg","svg").createSVGRect||!c.implementation.hasFeature("http://www.w3.org/TR/SVG11/feature#Image","1.1")||t.opera&&-1===i.userAgent.indexOf("Chrome")||-1!==i.userAgent.indexOf("Series40")),l=new s;l.onerror=function(){o.method="png",o.href=r[2],e(r[2])},l.onload=function(){var t=1===l.width&&1===l.height,i=r[t&&d?0:t?1:2];t&&d?o.method="svg":t?o.method="datapng":o.method="png",o.href=i,n(e(i),a)},l.src="...",c.documentElement.className+=" grunticon"}};o.loadCSS=e,o.onloadCSS=n,t.grunticon=o}(this),function(e,n){"use strict";var t=n.document,o="grunticon:",r=function(e){if(t.attachEvent?"complete"===t.readyState:"loading"!==t.readyState)e();else{var n=!1;t.addEventListener("readystatechange",function(){n||(n=!0,e())},!1)}},a=function(e){return n.document.querySelector('link[href$="'+e+'"]')},i=function(e){var n,t,r,a,i,c,s={};if(n=e.sheet,!n)return s;t=n.cssRules?n.cssRules:n.rules;for(var d=0;d<t.length;d++)r=t[d].cssText,a=o+t[d].selectorText,i=r.split(");")[0].match(/US\-ASCII\,([^"']+)/),i&&i[1]&&(c=decodeURIComponent(i[1]),s[a]=c);return s},c=function(e){var n,r,a,i;a="data-grunticon-embed";for(var c in e){i=c.slice(o.length);try{n=t.querySelectorAll(i)}catch(s){continue}r=[];for(var d=0;d<n.length;d++)null!==n[d].getAttribute(a)&&r.push(n[d]);if(r.length)for(d=0;d<r.length;d++)r[d].innerHTML=e[c],r[d].style.backgroundImage="none",r[d].removeAttribute(a)}return r},s=function(n){"svg"===e.method&&r(function(){c(i(a(e.href))),"function"==typeof n&&n()})};e.embedIcons=c,e.getCSS=a,e.getIcons=i,e.ready=r,e.svgLoadedCallback=s,e.embedSVG=s}(grunticon,this)}();
# </script>
# <script>
#     grunticon(["/blueprint/cna/css/icons-data-svg.css", "/blueprint/cna/css/icons-data-png.css", "/blueprint/cna/css/icons-fallback.css"], grunticon.svgLoadedCallback);
# </script>
# <noscript><link href="/blueprint/cna/css/icons-fallback.css" rel="stylesheet"/></noscript>
# <!-- tag manager start -->
# <script src="//assets.adobedtm.com/2926360f3839/c1ab5d4d2c4f/launch-ff0787267299.min.js"></script>
# <!-- tag manager end -->
# <script type="text/javascript">
#     (function () {
#         var s = document.createElement('script');
#         s.type = 'text/javascript';
#         s.async = true;
#         s.src = 'https://s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5e0028e53cd1fd98';
#         var x = document.getElementsByTagName('script')[0];
#         x.parentNode.insertBefore(s, x);
#     })();
# </script>
# <script>
#     window.pwidget_config = {
#         clean: true,
#         track: false,
#         trackAddressBar: false,
#         lazy: true,
#         publisherKey: 'feb7gsrciersed26649v',
#         defaults: {
#             services: {
#                 twitter: {
#                     via: 'ChannelNewsAsia'
#                 }
#             }
#         }
#     };
# </script>
# <!--
# To collect end-user usage analytics about your application,
# insert the following script into each page you want to track.
# Place this code immediately before the closing </head> tag,
# and before any other scripts. Your first data will appear
# automatically in just a few seconds.
# -->
# <script type="text/javascript">
#     var appInsights=window.appInsights||function(config){
#         function i(config){t[config]=function(){var i=arguments;t.queue.push(function(){t[config].apply(t,i)})}}var t={config:config},u=document,e=window,o="script",s="AuthenticatedUserContext",h="start",c="stop",l="Track",a=l+"Event",v=l+"Page",y=u.createElement(o),r,f;y.src=config.url||"https://az416426.vo.msecnd.net/scripts/a/ai.0.js";u.getElementsByTagName(o)[0].parentNode.appendChild(y);try{t.cookie=u.cookie}catch(p){}for(t.queue=[],t.version="1.0",r=["Event","Exception","Metric","PageView","Trace","Dependency"];r.length;)i("track"+r.pop());return i("set"+s),i("clear"+s),i(h+a),i(c+a),i(h+v),i(c+v),i("flush"),config.disableExceptionTracking||(r="onerror",i("_"+r),f=e[r],e[r]=function(config,i,u,e,o){var s=f&&f(config,i,u,e,o);return s!==!0&&t["_"+r](config,i,u,e,o),s}),t
#     }({
#         instrumentationKey:"c919d4ee-1547-4a06-9117-a5032c55624f"
#     });
#
#     window.appInsights=appInsights;
#     appInsights.trackPageView();
# </script>
# <!--***********BEGIN JAVASCRIPT SNIPPET FOR DOMAIN channelnewsasia.com **************-->
# <script>
#                   (function(){
#                     if(window.BOOMR && window.BOOMR.version){return;}
#                     var dom,doc,where,iframe = document.createElement("iframe"),win = window;
#
#                     function boomerangSaveLoadTime(e) {
#                       win.BOOMR_onload=(e && e.timeStamp) || new Date().getTime();
#                     }
#                     if (win.addEventListener) {
#                       win.addEventListener("load", boomerangSaveLoadTime, false);
#                     } else if (win.attachEvent) {
#                       win.attachEvent("onload", boomerangSaveLoadTime);
#                     }
#
#                     iframe.src = "javascript:false";
#                     iframe.title = ""; iframe.role="presentation";
#                     (iframe.frameElement || iframe).style.cssText = "width:0;height:0;border:0;display:none;";
#                     where = document.getElementsByTagName("script")[0];
#                     where.parentNode.insertBefore(iframe, where);
#
#                     try {
#                       doc = iframe.contentWindow.document;
#                     } catch(e) {
#                       dom = document.domain;
#                       iframe.src="javascript:var d=document.open();d.domain='"+dom+"';void(0);";
#                       doc = iframe.contentWindow.document;
#                     }
#                     doc.open()._l = function() {
#                       var js = this.createElement("script");
#                       if(dom) this.domain = dom;
#                       js.id = "boomr-if-as";
#                       js.src = "//c.go-mpulse.net/boomerang/" +
#                         "9NQGB-9XFT8-Z9JTK-WR6HF-SRXRY";
#                       BOOMR_lstart=new Date().getTime();
#                       this.body.appendChild(js);
#                     };
#                     doc.write('<body onload="document._l();">');
#                     doc.close();
#                   })();
#                 </script>
# <!--***********    END JAVASCRIPT SNIPPET FOR DOMAIN channelnewsasia.com **************--><!--
# Helper script to expose video related functionalities
# so that it will be much easier for web developers/designers
# to perform video related tasks.
# -->
# <script>
# ...
# </span>
# </li>
# <li class="linkedin">
# <span class="sharelink-wrap">
# <a addthis:title="Cano Health to list via US$4.4 billion merger with Barry Sternlicht-backed SPAC" addthis:url="https://www.channelnewsasia.com/news/business/cano-health-to-list-via-us-4-4-billion-merger-with-barry-sternlicht-backed-spac-13525866" class="addthis_button_linkedin"><span class="i-linkedin" data-grunticon-embed="true"></span></a>
# </span>
# </li>
# </ul>
# </div>
# </div>
# <div class="c-save-for-later--default is-teaser-position" data-css="c-save-for-later" data-js-module="save-for-later" data-js-options='{"articleID":"13525866"}'>
# <button class="save-for-later__toggle i-save-for-later" data-grunticon-embed="true" data-js-atom="save-for-later-toggle" title="Bookmark article to read later"></button>
# </div>
# </div>
# </div>
# </div>
# </div></div>
# <div class="grid__col-3">
# <div class="c-teaser--default" data-css="c-teaser" data-js-module="teaser">
# <a class="teaser__picture-wrapper" href="/news/business/who-says-faces--onslaught--of-cyberattacks-as-taiwan-complains-of-censorship-13525690">
# <div class="c-picture--default" data-css="c-picture">
# <figure class="picture__wrapper">
# <picture class="picture__container">
# <source data-srcset="https://cna-sg-res.cloudinary.com/image/upload/q_auto,f_auto/image/8695368/16x9/100/57/e9615d3f8fac5a826ae3bfa657aec6ec/RQ/business.png 100w, https://cna-sg-res.cloudinary.com/image/upload/q_auto,f_auto/image/8695368/16x9/237/134/e9615d3f8fac5a826ae3bfa657aec6ec/XP/business.png 237w, https://cna-sg-res.cloudinary.com/image/upload/q_auto,f_auto/image/8695368/16x9/270/152/e9615d3f8fac5a826ae3bfa657aec6ec/FU/business.png 270w, https://cna-sg-res.cloudinary.com/image/upload/q_auto,f_auto/image/8695368/16x9/293/165/e9615d3f8fac5a826ae3bfa657aec6ec/gh/business.png 293w, https://cna-sg-res.cloudinary.com/image/upload/q_auto,f_auto/image/8695368/16x9/330/186/e9615d3f8fac5a826ae3bfa657aec6ec/YM/business.png 330w, https://cna-sg-res.cloudinary.com/image/upload/q_auto,f_auto/image/8695368/16x9/400/225/e9615d3f8fac5a826ae3bfa657aec6ec/dQ/business.png 400w, https://cna-sg-res.cloudinary.com/image/upload/q_auto,f_auto/image/8695368/16x9/450/253/e9615d3f8fac5a826ae3bfa657aec6ec/wa/business.png 450w, https://cna-sg-res.cloudinary.com/image/upload/q_auto,f_auto/image/8695368/16x9/470/264/e9615d3f8fac5a826ae3bfa657aec6ec/cu/business.png 470w, https://cna-sg-res.cloudinary.com/image/upload/q_auto,f_auto/image/8695368/16x9/550/309/e9615d3f8fac5a826ae3bfa657aec6ec/SV/business.png 550w, https://cna-sg-res.cloudinary.com/image/upload/q_auto,f_auto/image/8695368/16x9/670/377/e9615d3f8fac5a826ae3bfa657aec6ec/lx/business.png 670w, https://cna-sg-res.cloudinary.com/image/upload/q_auto,f_auto/image/8695368/16x9/738/415/e9615d3f8fac5a826ae3bfa657aec6ec/Iz/business.png 738w" sizes="(min-width: 1235px) 274px,(min-width: 992px) calc( (100vw - 50px - 90px) / 4 ),(min-width: 768px) calc( (100vw - 50px - 60px) / 3), 100px"/>
# <img alt="New Content Item" class="picture__image lazyload" src="..."/>
# </picture>
# </figure>
# </div>
# </a>
# <div class="teaser__content-wrapper">
# <div>
# <div class="teaser__category-container">
# <a class="teaser__category" href="/news/business">Business</a>
# </div>
# <h3 class="teaser__heading">
# <a class="teaser__title" href="/news/business/who-says-faces--onslaught--of-cyberattacks-as-taiwan-complains-of-censorship-13525690">WHO says faces 'onslaught' of cyberattacks as Taiwan complains of censorship</a>
# </h3>
# <div class="teaser__additional-info">
# <time class="teaser__time" data-js-atom="time" datetime="1605184850"></time>
# <div class="c-sharing--menu is-teaser-position" data-css="c-sharelist" data-js-module="sharing">
# <button aria-controls="sharing-panel--1082783390" aria-expanded="false" class="sharing__toggle-btn" data-js-atom="sharing-toggle">
# <span class="sharing__open i-share" data-grunticon-embed="true"></span>
# <span class="sharing__close"><span class="sharing__close-icon"></span></span>
#                 Toggle share menu</button>
# <div class="sharing__panel" data-js-atom="sharing-panel" id="sharing-panel--1082783390">
# <ul class="sharelist">
# <li class="whatsapp">
# <span class="sharelink-wrap">
# <a addthis:title="WHO says faces 'onslaught' of cyberattacks as Taiwan complains of censorship" addthis:url="https://www.channelnewsasia.com/news/business/who-says-faces--onslaught--of-cyberattacks-as-taiwan-complains-of-censorship-13525690" class="addthis_button_whatsapp"><span class="i-whatsapp" data-grunticon-embed="true"></span></a>
# </span>
# </li>
# <li class="facebook">
# <span class="sharelink-wrap">
# <a addthis:title="WHO says faces 'onslaught' of cyberattacks as Taiwan complains of censorship" addthis:url="https://www.channelnewsasia.com/news/business/who-says-faces--onslaught--of-cyberattacks-as-taiwan-complains-of-censorship-13525690" class="addthis_button_facebook"><span class="i-facebook" data-grunticon-embed="true"></span></a>
# </span>
# </li>
# <li class="twitter">
# <span class="sharelink-wrap">
# <a addthis:title="WHO says faces 'onslaught' of cyberattacks as Taiwan complains of censorship" addthis:url="https://www.channelnewsasia.com/news/business/who-says-faces--onslaught--of-cyberattacks-as-taiwan-complains-of-censorship-13525690" class="addthis_button_twitter"><span class="i-twitter" data-grunticon-embed="true"></span></a>
# </span>
# </li>
# <li class="email">
# <span class="sharelink-wrap">
# <a addthis:title="WHO says faces 'onslaught' of cyberattacks as Taiwan complains of censorship" addthis:url="https://www.channelnewsasia.com/news/business/who-says-faces--onslaught--of-cyberattacks-as-taiwan-complains-of-censorship-13525690" class="addthis_button_email"><span class="i-email" data-grunticon-embed="true"></span></a>
# </span>
# </li>
# <li class="linkedin">
# <span class="sharelink-wrap">
# <a addthis:title="WHO says faces 'onslaught' of cyberattacks as Taiwan complains of censorship" addthis:url="https://www.channelnewsasia.com/news/business/who-says-faces--onslaught--of-cyberattacks-as-taiwan-complains-of-censorship-13525690" class="addthis_button_linkedin"><span class="i-linkedin" data-grunticon-embed="true"></span></a>
# </span>
# </li>
# </ul>
# </div>
# </div>
# <div class="c-save-for-later--default is-teaser-position" data-css="c-save-for-later" data-js-module="save-for-later" data-js-options='{"articleID":"13525690"}'>
# <button class="save-for-later__toggle i-save-for-later" data-grunticon-embed="true" data-js-atom="save-for-later-toggle" title="Bookmark article to read later"></button>
# </div>
# </div>
# </div>
# </div>
# </div></div>
# </div>
# <a class="section__cta" data-js-atom="section-cta" href="/archives/8395946/business?channelId=7469482">View more stories</a>
# </div>
# </div>
# </div><div class="u-grid is-hidden-smartphone is-full-width">
# <aside class="c-advertisement--leaderboard is-hidden-smartphone is-border-top-bottom" data-css="c-advertisement" data-js-module="advertisement" data-js-options='{
# "networkCode": "4654", "adChannel": "channel_newsasia", "adUnit": "leaderboard4", "adSection": "homepage", "sizes": [[970, 90], [728, 90]], "isElevator": false
# }'>
# <span class="advertisement__title">Advertisement</span>
# <div class="advertisement__container" data-js-atom="advertisement-wrapper" id="ad-desktop-tablet-leaderboard4"></div>
# </aside>
# </div>
#
# <div>
# </div>
#
# <footer class="c-footer--default" data-css="c-footer" data-js-module="footer" role="contentinfo">
# <div class="footer__region is-background-primary">
# <h2 class="is-aural">More information about CNA</h2>
# <div class="footer__wrapper">
# <button class="footer__go-to-top i-arrow-top-small-white" data-js-atom="to-top-btn">jump to top of page</button>
# <div class="footer__section is-half">
# <h3 class="footer__title">
#                     Sections</h3>
# <ul class="footer__list is-grid">
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/singapore">Singapore</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/asia">Asia</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/world">World</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/commentary">Commentary</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/business">Business</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/sport">Sport</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/climatechange">Climate Change</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/videos">News Clips</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/video-on-demand">VOD</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/podcasts">Podcasts</a>
# </li>
# </ul>
# <h3 class="footer__title">
#         About Us</h3>
# <ul class="footer__list is-grid">
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/about">About CNA</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/about/hotels">Hotel Partners</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/events-seminars">Events &amp; Seminars</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/about/presenters">Presenters &amp; Correspondents</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/about/contact-us">Contact Us</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/about/mediacorp-digital-network">Mediacorp Digital Network</a>
# </li>
# </ul>
# <h3 class="footer__title">
#         Advertise with us</h3>
# <ul class="footer__list is-grid-small">
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/advertise/contactsales">Contact Sales</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/advertise/onlineadvertising">Online Advertising</a>
# </li>
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/advertise/tvadvertising">TV Advertising</a>
# </li>
# </ul>
# </div>
# <div class="footer__section is-half">
# <div class="c-newsletter-dropdownformbox">
# <div class="c-newsletter--default" data-css="c-newsletter" data-js-module="newsletter">
# <h3 class="footer__title">Pressed for time? Stay informed with CNA's newsletters</h3>
# <div class="newsletter__response">
# <div class="newsletter__response-inner">
# </div>
# <button class="newsletter__response-back-btn" type="button">TRY AGAIN</button>
# </div>
# <form action="https://www.channelnewsasia.com/action/8396344/subscribe" class="c-newsletter-form--default cnanewsletter-selection" data-css="c-newsletter-form" id="newsletterForm" label="footer" method="get">
# <div class="form__row">
# <div class="form__box is-size-xl">
# <input id="shortCode" name="newsletterShortcode" required="" type="hidden" value="">
# <div class="form__box is-size-xl">
# <div class="form-field is-checkbox">
# <label for="data-check">
# <input class="is-aural" id="data-check" name="termsCondition" required="required" value="true"/>
# <span class="conditions-text">
#                                     This service is not intended for persons residing in the EU. By clicking subscribe, I agree to receive news updates and promotional material from Mediacorp and Mediacorp's partners.</span></label>
# </div>
# </div>
# <div class="form__box is-size-xl">
# <div class="form-field is-email">
# <div class="custom-select">
# <div class="select-selected" id="selectedNewsletter">Choose a newsletter  </div>
# <div class="select-items select-hide" id="newsletterItems">
# <div data-value="CNA_Partners">Morning Brief </div>
# <div data-value="CNA_BreakingNews">Breaking News alert </div>
# <div data-value="CNA_Insider">CNA Insider </div>
# <div data-value="CNA_Partners,CNA_BreakingNews,CNA_Insider">All of the above </div>
# </div>
# </div>
# <div class="email-field-area">
# <label class="is-aural" for="email-address">Please enter your email address</label>
# <input id="email-address" name="email" placeholder="Enter your email address" required="required" type="email"/>
# <button type="submit">Sign me up</button>
# </div>
# </div>
# </div>
# </input></div>
# </div>
# </form>
# </div>
# </div><h3 class="footer__title">
#         Follow our news</h3>
# <ul class="footer__list">
# <li class="footer__list-item">
# <a class="footer__link i-facebook is-circle-icon" data-grunticon-embed="true" href="https://www.facebook.com/ChannelNewsAsia" target="_blank">Facebook</a></li>
# <li class="footer__list-item">
# <a class="footer__link i-twitter is-circle-icon" data-grunticon-embed="true" href="https://www.twitter.com/Channelnewsasia" target="_blank">Twitter</a></li>
# <li class="footer__list-item">
# <a class="footer__link i-linkedin is-circle-icon" data-grunticon-embed="true" href="https://www.linkedin.com/company/channel-newsasia/" target="_blank">LinkedIn</a></li>
# <li class="footer__list-item">
# <a class="footer__link i-youtube is-circle-icon" data-grunticon-embed="true" href="https://www.youtube.com/user/channelnewsasia" target="_blank">YouTube</a></li>
# <li class="footer__list-item">
# <a class="footer__link i-rss is-circle-icon" data-grunticon-embed="true" href="https://www.channelnewsasia.com/news/rss" target="_blank">RSS</a></li>
# </ul>
# <h3 class="footer__title">Experience news with our apps</h3>
# <ul class="footer__list is-grid-small">
# <li class="footer__list-item">
# <a class="footer__link i-google-store" href="https://play.google.com/store/apps/details?id=com.channelnewsasia" target="_blank">Play Store</a></li>
# <li class="footer__list-item">
# <a class="footer__link i-apple-store" href="https://itunes.apple.com/us/app/channel-newsasia/id520773971?mt=8" target="_blank">App Store</a></li>
# <li class="footer__list-item">
# <a class="footer__link i-huawei-app-gallery" href="https://appgallery.huawei.com/#/app/C101326503?appId=C101326503&amp;source=appshare&amp;subsource=C101326503" target="_blank">Huawei App Gallery</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="footer__region is-background-secondary">
# <div class="footer__wrapper">
# <div class="footer__section is-full">
# <p class="footer__text">Copyright© Mediacorp 2020. Mediacorp Pte Ltd. All rights reserved.</p>
# <ul class="footer__list">
# <li class="footer__list-item">
# <a class="footer__link" href="https://www.channelnewsasia.com/news/about/termsandconditions">Terms and Conditions</a>
# </li>
# <li class="footer__list-item">
# <a href="https://www.mediacorp.sg/en/privacy-policy-5933440">
# <i class="icon footer__link"></i>
# <span>
#           Privacy Policy</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer><div></div>
# <div></div>
# <div></div>
# <div></div>
# <!-- Scripts
#         ================================================== -->
# <!-- repository scripts start -->
# <script src="/resources/7469166/0/-745998258/news.js" type="text/javascript"></script>
# <!-- repository scripts end -->
# <script src="/blueprint/cna/js/vendor/libs.js"></script>
# <script src="/blueprint/cna/js/main.js"></script>
# <!-- Twitter : latest tweets -->
# <script async="" charset="utf-8" src="//platform.twitter.com/widgets.js"></script>
# <script src="/blueprint/cna/js/videotagging/videotagging.js"></script>
# <script>
#     if (typeof _satellite != "undefined") {
#         _satellite.pageBottom();
#     }
# </script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"errorBeacon":"bam-cell.nr-data.net","licenseKey":"ab7b570406","agent":"","beacon":"bam-cell.nr-data.net","applicationTime":777,"applicationID":"47940004","transactionName":"NVEGZxNZDEMEBhZbCQwbN0MTUQxXJgoMRhQNWAhWExcyUQIAKlMIBlgBQU5QA14BCQdgAxNBAUAV","queueTime":0}</script>

# %% [markdown]
# As mentioned earlier, the data are contained within the `<a>` and `<time>` HTML elements and these elements have the corresponding attribute `class` with the values `teaser__title` and `teaser__time` respectively.
#
# Because we already know which elements and attributes has the data, we are able to directly extract the elements from the HTML document. The return `data` is not a Python datatype but a BeautifulSoup `ResultSet`.

# %%
data = soup.find_all(['a', 'time'], {'class': ['teaser__title', 'teaser__time']})

# check that the data we scraped is correct
print(type(data))
print(len(data))
print(data[:2])
print(data[-2:])
# Out:
# <class 'bs4.element.ResultSet'>
# 116
# [<a class="teaser__title" href="/news/business/singapore-airlines-bond-issue-850-million-investor-13530640">Singapore Airlines raises S$850 million through convertible bond issue</a>, <time class="teaser__time" data-js-atom="time" datetime="1605229435"></time>]
# [<a class="teaser__title" href="/news/business/who-says-faces--onslaught--of-cyberattacks-as-taiwan-complains-of-censorship-13525690">WHO says faces 'onslaught' of cyberattacks as Taiwan complains of censorship</a>, <time class="teaser__time" data-js-atom="time" datetime="1605184850"></time>]

# %% [markdown]
# Once we are certain that the data obtained is correct, we can extract the article's titles and its time information. We will be storing this data in a `CSV` file therefore a proper delimiter should be chosen.

# %%
delimiter = '*'
header = 'article_name'+delimiter+'epoch_time\n'
data_to_write = [header]
temp = None

for item in data:
    if item.name =='a':
        temp = item.get_text() + delimiter
    else:
        temp += item['datetime'] + '\n'
        data_to_write.append(temp)
        temp = None

# %% [markdown]
# Before writing the data to a `CSV` file, we need to construct a unique file name. One way of doing this is by appending the date and time (timepstamp) to the file name. This helps us keep track of the age of the data.

# %%
# constructing the file name
timestamp = datetime.now().strftime("%d-%b-%Y_%H-%M-%S")
filename = 'scrape_'+timestamp+'.csv'

# writing the data to file
with open(filename, 'w') as fo:
    for line in data_to_write:
        fo.writelines(line)

# %% [markdown]
# The data can now be used for the next part of the process such as data cleaning and analysis.
